# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

#이미지가 저장될 폴더가 없다면 만듭니다.
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

np.random.seed(3)
tf.random.set_seed(3)

#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()


#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터 불러오기

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀값은 0에서 255사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  #X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          #가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          #판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

gan_train(4001, 32, 200)  #4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번 마다 결과가 저장되게 하였습니다.
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# epoch:0  d_loss:0.7053  g_loss:0.6912
# epoch:1  d_loss:0.4627  g_loss:0.3281
# epoch:2  d_loss:0.5696  g_loss:0.1029
# epoch:3  d_loss:0.6584  g_loss:0.0848
# epoch:4  d_loss:0.5765  g_loss:0.1661
# epoch:5  d_loss:0.5082  g_loss:0.4213
# epoch:6  d_loss:0.4877  g_loss:0.6959
# epoch:7  d_loss:0.5097  g_loss:0.8674
# epoch:8  d_loss:0.4984  g_loss:0.8906
# epoch:9  d_loss:0.4903  g_loss:0.8557
# epoch:10  d_loss:0.4238  g_loss:0.7684
# epoch:11  d_loss:0.4480  g_loss:0.7806
# epoch:12  d_loss:0.5051  g_loss:0.8334
# epoch:13  d_loss:0.4948  g_loss:0.8716
# epoch:14  d_loss:0.5907  g_loss:0.9240
# epoch:15  d_loss:0.4872  g_loss:1.0397
# epoch:16  d_loss:0.4183  g_loss:1.0090
# epoch:17  d_loss:0.6367  g_loss:0.8152
# epoch:18  d_loss:0.5633  g_loss:0.6655
# epoch:19  d_loss:0.4632  g_loss:0.7082
# epoch:20  d_loss:0.4441  g_loss:0.7646
# epoch:21  d_loss:0.4955  g_loss:0.7811
# epoch:22  d_loss:0.5003  g_loss:0.6346
# epoch:23  d_loss:0.4542  g_loss:0.6158
# epoch:24  d_loss:0.4503  g_loss:0.6561
# epoch:25  d_loss:0.4584  g_loss:0.6497
# epoch:26  d_loss:0.4937  g_loss:0.7482
# epoch:27  d_loss:0.4647  g_loss:0.5758
# epoch:28  d_loss:0.4595  g_loss:0.5770
# epoch:29  d_loss:0.4884  g_loss:0.5683
# epoch:30  d_loss:0.4217  g_loss:0.6023
# epoch:31  d_loss:0.4420  g_loss:0.6580
# epoch:32  d_loss:0.3821  g_loss:0.6016
# epoch:33  d_loss:0.3737  g_loss:0.7502
# epoch:34  d_loss:0.2780  g_loss:0.7779
# epoch:35  d_loss:0.3210  g_loss:0.8649
# epoch:36  d_loss:0.3456  g_loss:0.7488
# epoch:37  d_loss:0.2545  g_loss:0.8058
# epoch:38  d_loss:0.2642  g_loss:1.0159
# epoch:39  d_loss:0.1818  g_loss:1.3050
# epoch:40  d_loss:0.2306  g_loss:1.4105
# epoch:41  d_loss:0.3561  g_loss:0.9605
# epoch:42  d_loss:0.3378  g_loss:0.7801
# epoch:43  d_loss:0.2374  g_loss:0.7876
# epoch:44  d_loss:0.2263  g_loss:1.0091
# epoch:45  d_loss:0.3253  g_loss:1.4454
# epoch:46  d_loss:0.6807  g_loss:0.9182
# epoch:47  d_loss:0.3288  g_loss:1.6260
# epoch:48  d_loss:0.1367  g_loss:2.6352
# epoch:49  d_loss:0.1287  g_loss:2.6238
# epoch:50  d_loss:0.0570  g_loss:2.6541
# epoch:51  d_loss:0.0656  g_loss:2.6605
# epoch:52  d_loss:0.0907  g_loss:2.8681
# epoch:53  d_loss:0.1636  g_loss:2.8306
# epoch:54  d_loss:0.2850  g_loss:3.7847
# epoch:55  d_loss:0.3335  g_loss:3.1469
# epoch:56  d_loss:0.6251  g_loss:2.0236
# epoch:57  d_loss:0.7243  g_loss:2.5539
# epoch:58  d_loss:0.6244  g_loss:3.0790
# epoch:59  d_loss:0.5979  g_loss:2.5645
# epoch:60  d_loss:0.4389  g_loss:2.4894
# epoch:61  d_loss:0.4389  g_loss:2.8850
# epoch:62  d_loss:0.2793  g_loss:3.4465
# epoch:63  d_loss:0.2248  g_loss:3.6122
# epoch:64  d_loss:0.5448  g_loss:2.4121
# epoch:65  d_loss:0.5760  g_loss:1.8719
# epoch:66  d_loss:0.6031  g_loss:1.7437
# epoch:67  d_loss:0.4978  g_loss:2.6854
# epoch:68  d_loss:0.3109  g_loss:3.2152
# epoch:69  d_loss:0.9046  g_loss:1.1356
# epoch:70  d_loss:1.0639  g_loss:0.6898
# epoch:71  d_loss:0.5174  g_loss:1.1633
# epoch:72  d_loss:0.6881  g_loss:1.6528
# epoch:73  d_loss:0.6318  g_loss:1.6831
# epoch:74  d_loss:0.7421  g_loss:1.2702
# epoch:75  d_loss:0.6925  g_loss:1.3211
# epoch:76  d_loss:0.5567  g_loss:1.5541
# epoch:77  d_loss:0.3115  g_loss:2.7238
# epoch:78  d_loss:0.3313  g_loss:3.2496
# epoch:79  d_loss:0.2469  g_loss:2.8849
# epoch:80  d_loss:0.2645  g_loss:2.5889
# epoch:81  d_loss:0.3564  g_loss:2.4515
# epoch:82  d_loss:0.3179  g_loss:2.6260
# epoch:83  d_loss:0.2310  g_loss:3.5985
# epoch:84  d_loss:0.3671  g_loss:3.8990
# epoch:85  d_loss:0.8524  g_loss:2.7112
# epoch:86  d_loss:0.5680  g_loss:2.8398
# epoch:87  d_loss:0.6586  g_loss:2.8196
# epoch:88  d_loss:0.8906  g_loss:2.3289
# epoch:89  d_loss:0.9275  g_loss:2.4391
# epoch:90  d_loss:0.6188  g_loss:3.0585
# epoch:91  d_loss:0.7260  g_loss:3.3033
# epoch:92  d_loss:0.9249  g_loss:1.7965
# epoch:93  d_loss:0.9264  g_loss:1.5822
# epoch:94  d_loss:0.8499  g_loss:1.4075
# epoch:95  d_loss:0.6067  g_loss:1.5011
# epoch:96  d_loss:0.6740  g_loss:1.7635
# epoch:97  d_loss:0.6643  g_loss:1.9592
# epoch:98  d_loss:0.6021  g_loss:1.9462
# epoch:99  d_loss:0.6158  g_loss:1.8217
# epoch:100  d_loss:0.6218  g_loss:1.3679
# epoch:101  d_loss:0.4779  g_loss:1.4896
# epoch:102  d_loss:0.4362  g_loss:1.4424
# epoch:103  d_loss:0.5485  g_loss:1.4842
# epoch:104  d_loss:0.4126  g_loss:1.5327
# epoch:105  d_loss:0.4718  g_loss:1.5287
# epoch:106  d_loss:0.4956  g_loss:1.3600
# epoch:107  d_loss:0.3849  g_loss:1.6566
# epoch:108  d_loss:0.4741  g_loss:1.3686
# epoch:109  d_loss:0.3866  g_loss:1.2492
# epoch:110  d_loss:0.4417  g_loss:1.3090
# epoch:111  d_loss:0.3799  g_loss:1.3903
# epoch:112  d_loss:0.3885  g_loss:1.5824
# epoch:113  d_loss:0.4309  g_loss:1.3211
# epoch:114  d_loss:0.5841  g_loss:1.0342
# epoch:115  d_loss:0.5409  g_loss:1.0011
# epoch:116  d_loss:0.4626  g_loss:1.0488
# epoch:117  d_loss:0.4878  g_loss:1.0996
# epoch:118  d_loss:0.5319  g_loss:1.1267
# epoch:119  d_loss:0.4382  g_loss:1.2896
# epoch:120  d_loss:0.5063  g_loss:1.2737
# epoch:121  d_loss:0.5429  g_loss:1.1747
# epoch:122  d_loss:0.6939  g_loss:1.2403
# epoch:123  d_loss:0.6333  g_loss:1.0705
# epoch:124  d_loss:0.5060  g_loss:1.0669
# epoch:125  d_loss:0.6483  g_loss:1.0205
# epoch:126  d_loss:0.5739  g_loss:1.1310
# epoch:127  d_loss:0.4511  g_loss:1.3363
# epoch:128  d_loss:0.5077  g_loss:1.3927
# epoch:129  d_loss:0.4347  g_loss:1.6786
# epoch:130  d_loss:0.4325  g_loss:1.7422
# epoch:131  d_loss:0.5215  g_loss:1.7925
# epoch:132  d_loss:0.4978  g_loss:1.6361
# epoch:133  d_loss:0.4398  g_loss:1.7534
# epoch:134  d_loss:0.4581  g_loss:1.6958
# epoch:135  d_loss:0.4072  g_loss:2.1199
# epoch:136  d_loss:0.4170  g_loss:2.1315
# epoch:137  d_loss:0.3961  g_loss:2.1247
# epoch:138  d_loss:0.4743  g_loss:1.9978
# epoch:139  d_loss:0.3748  g_loss:2.3173
# epoch:140  d_loss:0.3962  g_loss:2.0968
# epoch:141  d_loss:0.4308  g_loss:2.0798
# epoch:142  d_loss:0.5936  g_loss:1.7416
# epoch:143  d_loss:0.4582  g_loss:2.1532
# epoch:144  d_loss:0.4840  g_loss:2.1453
# epoch:145  d_loss:0.3438  g_loss:2.3536
# epoch:146  d_loss:0.4924  g_loss:2.0585
# epoch:147  d_loss:0.6000  g_loss:2.0982
# epoch:148  d_loss:0.5245  g_loss:1.8453
# epoch:149  d_loss:0.4297  g_loss:1.9867
# epoch:150  d_loss:0.5193  g_loss:1.8183
# epoch:151  d_loss:0.5634  g_loss:1.8971
# epoch:152  d_loss:0.5641  g_loss:1.6398
# epoch:153  d_loss:0.6060  g_loss:1.8242
# epoch:154  d_loss:0.4565  g_loss:1.6334
# epoch:155  d_loss:0.5103  g_loss:1.8005
# epoch:156  d_loss:0.4647  g_loss:1.9043
# epoch:157  d_loss:0.4547  g_loss:1.8409
# epoch:158  d_loss:0.4202  g_loss:1.6037
# epoch:159  d_loss:0.4015  g_loss:2.0199
# epoch:160  d_loss:0.3791  g_loss:1.8818
# epoch:161  d_loss:0.4713  g_loss:1.6887
# epoch:162  d_loss:0.4177  g_loss:1.9680
# epoch:163  d_loss:0.3467  g_loss:2.1085
# epoch:164  d_loss:0.3798  g_loss:2.0507
# epoch:165  d_loss:0.3459  g_loss:2.0708
# epoch:166  d_loss:0.4216  g_loss:1.9225
# epoch:167  d_loss:0.4826  g_loss:1.8294
# epoch:168  d_loss:0.3837  g_loss:1.7447
# epoch:169  d_loss:0.4045  g_loss:2.1044
# epoch:170  d_loss:0.4355  g_loss:1.6929
# epoch:171  d_loss:0.4829  g_loss:1.6337
# epoch:172  d_loss:0.4210  g_loss:1.6393
# epoch:173  d_loss:0.4776  g_loss:1.6788
# epoch:174  d_loss:0.4558  g_loss:1.6939
# epoch:175  d_loss:0.4677  g_loss:1.3748
# epoch:176  d_loss:0.5233  g_loss:1.5703
# epoch:177  d_loss:0.6186  g_loss:1.2935
# epoch:178  d_loss:0.4585  g_loss:1.6929
# epoch:179  d_loss:0.5325  g_loss:1.3869
# epoch:180  d_loss:0.5651  g_loss:1.2718
# epoch:181  d_loss:0.5114  g_loss:1.5316
# epoch:182  d_loss:0.5785  g_loss:1.7462
# epoch:183  d_loss:0.5400  g_loss:1.5576
# epoch:184  d_loss:0.4674  g_loss:1.5666
# epoch:185  d_loss:0.5987  g_loss:1.2137
# epoch:186  d_loss:0.5445  g_loss:1.0401
# epoch:187  d_loss:0.5147  g_loss:1.4139
# epoch:188  d_loss:0.5406  g_loss:1.4198
# epoch:189  d_loss:0.4241  g_loss:1.6408
# epoch:190  d_loss:0.4364  g_loss:1.6648
# epoch:191  d_loss:0.5122  g_loss:1.4113
# epoch:192  d_loss:0.4361  g_loss:1.6635
# epoch:193  d_loss:0.5727  g_loss:1.3565
# epoch:194  d_loss:0.4508  g_loss:1.5381
# epoch:195  d_loss:0.4291  g_loss:1.9329
# epoch:196  d_loss:0.3641  g_loss:2.0551
# epoch:197  d_loss:0.3359  g_loss:2.1545
# epoch:198  d_loss:0.3306  g_loss:1.9778
# epoch:199  d_loss:0.3784  g_loss:2.2253
# epoch:200  d_loss:0.5300  g_loss:1.9732
# epoch:201  d_loss:0.5323  g_loss:1.8119
# epoch:202  d_loss:0.5852  g_loss:2.2076
# epoch:203  d_loss:0.5500  g_loss:2.1099
# epoch:204  d_loss:0.6144  g_loss:2.1976
# epoch:205  d_loss:0.5033  g_loss:2.1191
# epoch:206  d_loss:0.5285  g_loss:1.7702
# epoch:207  d_loss:0.6649  g_loss:1.6287
# epoch:208  d_loss:0.7036  g_loss:1.3742
# epoch:209  d_loss:0.3866  g_loss:1.7805
# epoch:210  d_loss:0.5247  g_loss:1.7912
# epoch:211  d_loss:0.4844  g_loss:2.0192
# epoch:212  d_loss:0.4754  g_loss:2.1180
# epoch:213  d_loss:0.6864  g_loss:1.8730
# epoch:214  d_loss:0.5330  g_loss:1.5974
# epoch:215  d_loss:0.3679  g_loss:1.9678
# epoch:216  d_loss:0.5380  g_loss:2.1399
# epoch:217  d_loss:0.4359  g_loss:2.5541
# epoch:218  d_loss:0.3860  g_loss:2.4950
# epoch:219  d_loss:0.4645  g_loss:2.3599
# epoch:220  d_loss:0.4868  g_loss:2.3274
# epoch:221  d_loss:0.3824  g_loss:2.7790
# epoch:222  d_loss:0.3535  g_loss:2.1690
# epoch:223  d_loss:0.5117  g_loss:2.2062
# epoch:224  d_loss:0.3685  g_loss:2.5719
# epoch:225  d_loss:0.2529  g_loss:2.7334
# epoch:226  d_loss:0.3550  g_loss:2.3716
# epoch:227  d_loss:0.4045  g_loss:2.3999
# epoch:228  d_loss:0.4178  g_loss:2.5177
# epoch:229  d_loss:0.3269  g_loss:2.4454
# epoch:230  d_loss:0.3768  g_loss:2.5439
# epoch:231  d_loss:0.5349  g_loss:2.2092
# epoch:232  d_loss:0.4251  g_loss:1.8618
# epoch:233  d_loss:0.5330  g_loss:2.0059
# epoch:234  d_loss:0.4256  g_loss:2.1042
# epoch:235  d_loss:0.4568  g_loss:2.0396
# epoch:236  d_loss:0.4780  g_loss:1.6002
# epoch:237  d_loss:0.3838  g_loss:2.4211
# epoch:238  d_loss:0.5104  g_loss:2.5869
# epoch:239  d_loss:0.4354  g_loss:2.6127
# epoch:240  d_loss:0.5043  g_loss:2.3612
# epoch:241  d_loss:0.6000  g_loss:1.9485
# epoch:242  d_loss:0.5527  g_loss:1.7901
# epoch:243  d_loss:0.5323  g_loss:1.4091
# epoch:244  d_loss:0.5991  g_loss:1.6821
# epoch:245  d_loss:0.3554  g_loss:1.9239
# epoch:246  d_loss:0.3591  g_loss:2.5795
# epoch:247  d_loss:0.4437  g_loss:2.2667
# epoch:248  d_loss:0.4996  g_loss:2.0244
# epoch:249  d_loss:0.4990  g_loss:2.1449
# epoch:250  d_loss:0.4103  g_loss:2.2374
# epoch:251  d_loss:0.3628  g_loss:2.5749
# epoch:252  d_loss:0.3034  g_loss:2.4163
# epoch:253  d_loss:0.4161  g_loss:2.1903
# epoch:254  d_loss:0.4216  g_loss:2.0504
# epoch:255  d_loss:0.4511  g_loss:2.1317
# epoch:256  d_loss:0.4494  g_loss:2.1657
# epoch:257  d_loss:0.3684  g_loss:2.1678
# epoch:258  d_loss:0.4065  g_loss:2.3484
# epoch:259  d_loss:0.5138  g_loss:2.4945
# epoch:260  d_loss:0.5380  g_loss:2.4834
# epoch:261  d_loss:0.4417  g_loss:2.3030
# epoch:262  d_loss:0.4227  g_loss:2.4470
# epoch:263  d_loss:0.4533  g_loss:2.0909
# epoch:264  d_loss:0.3585  g_loss:2.2660
# epoch:265  d_loss:0.4018  g_loss:2.1609
# epoch:266  d_loss:0.2912  g_loss:2.8488
# epoch:267  d_loss:0.4534  g_loss:2.5549
# epoch:268  d_loss:0.3130  g_loss:1.8127
# epoch:269  d_loss:0.4864  g_loss:1.6382
# epoch:270  d_loss:0.4416  g_loss:1.9374
# epoch:271  d_loss:0.4223  g_loss:2.2077
# epoch:272  d_loss:0.3401  g_loss:2.6477
# epoch:273  d_loss:0.4635  g_loss:2.5045
# epoch:274  d_loss:0.6466  g_loss:2.4469
# epoch:275  d_loss:0.4551  g_loss:2.3727
# epoch:276  d_loss:0.7371  g_loss:1.6871
# epoch:277  d_loss:0.4944  g_loss:1.8837
# epoch:278  d_loss:0.4176  g_loss:1.8605
# epoch:279  d_loss:0.4205  g_loss:2.4265
# epoch:280  d_loss:0.3065  g_loss:2.5118
# epoch:281  d_loss:0.4372  g_loss:3.1257
# epoch:282  d_loss:0.3044  g_loss:2.6163
# epoch:283  d_loss:0.3351  g_loss:2.4186
# epoch:284  d_loss:0.4452  g_loss:2.0492
# epoch:285  d_loss:0.3814  g_loss:1.9104
# epoch:286  d_loss:0.3085  g_loss:2.3985
# epoch:287  d_loss:0.2750  g_loss:2.5660
# epoch:288  d_loss:0.3050  g_loss:3.1023
# epoch:289  d_loss:0.4218  g_loss:2.7274
# epoch:290  d_loss:0.5387  g_loss:2.9749
# epoch:291  d_loss:0.4960  g_loss:2.1942
# epoch:292  d_loss:0.5666  g_loss:1.6553
# epoch:293  d_loss:0.4074  g_loss:2.3452
# epoch:294  d_loss:0.4745  g_loss:2.4185
# epoch:295  d_loss:0.4864  g_loss:2.0555
# epoch:296  d_loss:0.4831  g_loss:1.6363
# epoch:297  d_loss:0.5408  g_loss:1.9488
# epoch:298  d_loss:0.6340  g_loss:2.1969
# epoch:299  d_loss:0.4873  g_loss:2.5831
# epoch:300  d_loss:0.6216  g_loss:2.3561
# epoch:301  d_loss:0.5882  g_loss:1.6353
# epoch:302  d_loss:0.5501  g_loss:1.3998
# epoch:303  d_loss:0.4981  g_loss:1.5457
# epoch:304  d_loss:0.3920  g_loss:1.8908
# epoch:305  d_loss:0.4201  g_loss:1.9896
# epoch:306  d_loss:0.2349  g_loss:2.3880
# epoch:307  d_loss:0.4779  g_loss:2.2739
# epoch:308  d_loss:0.3657  g_loss:2.2618
# epoch:309  d_loss:0.4176  g_loss:2.1161
# epoch:310  d_loss:0.3817  g_loss:1.9175
# epoch:311  d_loss:0.3667  g_loss:1.8516
# epoch:312  d_loss:0.2523  g_loss:1.8228
# epoch:313  d_loss:0.4175  g_loss:2.1894
# epoch:314  d_loss:0.4127  g_loss:2.0593
# epoch:315  d_loss:0.3675  g_loss:2.6090
# epoch:316  d_loss:0.2451  g_loss:2.5969
# epoch:317  d_loss:0.3230  g_loss:2.3656
# epoch:318  d_loss:0.3473  g_loss:2.1954
# epoch:319  d_loss:0.3888  g_loss:2.3927
# epoch:320  d_loss:0.3101  g_loss:2.5988
# epoch:321  d_loss:0.3186  g_loss:2.4673
# epoch:322  d_loss:0.4302  g_loss:1.9321
# epoch:323  d_loss:0.3235  g_loss:2.3235
# epoch:324  d_loss:0.3343  g_loss:2.0118
# epoch:325  d_loss:0.2873  g_loss:2.4988
# epoch:326  d_loss:0.2837  g_loss:2.4379
# epoch:327  d_loss:0.3795  g_loss:2.2952
# epoch:328  d_loss:0.3045  g_loss:3.4270
# epoch:329  d_loss:0.3059  g_loss:2.6935
# epoch:330  d_loss:0.2952  g_loss:2.7642
# epoch:331  d_loss:0.4510  g_loss:2.5190
# epoch:332  d_loss:0.2839  g_loss:2.3231
# epoch:333  d_loss:0.4613  g_loss:2.4524
# epoch:334  d_loss:0.4516  g_loss:1.8756
# epoch:335  d_loss:0.4478  g_loss:2.2296
# epoch:336  d_loss:0.3675  g_loss:2.2366
# epoch:337  d_loss:0.3576  g_loss:2.0891
# epoch:338  d_loss:0.4961  g_loss:2.0640
# epoch:339  d_loss:0.4564  g_loss:2.2639
# epoch:340  d_loss:0.2950  g_loss:2.3515
# epoch:341  d_loss:0.4877  g_loss:2.0847
# epoch:342  d_loss:0.4055  g_loss:2.6462
# epoch:343  d_loss:0.4106  g_loss:2.5991
# epoch:344  d_loss:0.3723  g_loss:2.6290
# epoch:345  d_loss:0.4913  g_loss:2.4080
# epoch:346  d_loss:0.4661  g_loss:1.7163
# epoch:347  d_loss:0.4217  g_loss:2.2725
# epoch:348  d_loss:0.5767  g_loss:2.6793
# epoch:349  d_loss:0.3647  g_loss:3.0131
# epoch:350  d_loss:0.5023  g_loss:2.5347
# epoch:351  d_loss:0.4769  g_loss:2.4246
# epoch:352  d_loss:0.5679  g_loss:1.6252
# epoch:353  d_loss:0.4022  g_loss:1.7137
# epoch:354  d_loss:0.5485  g_loss:1.9458
# epoch:355  d_loss:0.3349  g_loss:2.6554
# epoch:356  d_loss:0.4417  g_loss:2.2980
# epoch:357  d_loss:0.3579  g_loss:2.5902
# epoch:358  d_loss:0.5346  g_loss:2.2800
# epoch:359  d_loss:0.4288  g_loss:2.6613
# epoch:360  d_loss:0.5032  g_loss:2.4590
# epoch:361  d_loss:0.5029  g_loss:2.3152
# epoch:362  d_loss:0.4072  g_loss:2.1412
# epoch:363  d_loss:0.4782  g_loss:2.1403
# epoch:364  d_loss:0.4102  g_loss:2.5070
# epoch:365  d_loss:0.4121  g_loss:1.9000
# epoch:366  d_loss:0.4333  g_loss:2.1983
# epoch:367  d_loss:0.4928  g_loss:1.8162
# epoch:368  d_loss:0.3905  g_loss:1.7976
# epoch:369  d_loss:0.5689  g_loss:1.7918
# epoch:370  d_loss:0.4203  g_loss:2.3150
# epoch:371  d_loss:0.4296  g_loss:1.9837
# epoch:372  d_loss:0.5051  g_loss:2.0276
# epoch:373  d_loss:0.3686  g_loss:2.0193
# epoch:374  d_loss:0.3354  g_loss:2.2579
# epoch:375  d_loss:0.3529  g_loss:2.0766
# epoch:376  d_loss:0.4825  g_loss:1.7825
# epoch:377  d_loss:0.3380  g_loss:1.9429
# epoch:378  d_loss:0.2166  g_loss:2.2144
# epoch:379  d_loss:0.3662  g_loss:2.2906
# epoch:380  d_loss:0.3903  g_loss:2.6426
# epoch:381  d_loss:0.3677  g_loss:2.4980
# epoch:382  d_loss:0.3233  g_loss:2.1615
# epoch:383  d_loss:0.3624  g_loss:2.0396
# epoch:384  d_loss:0.4090  g_loss:1.9451
# epoch:385  d_loss:0.4711  g_loss:1.9283
# epoch:386  d_loss:0.3151  g_loss:2.1845
# epoch:387  d_loss:0.2998  g_loss:2.0700
# epoch:388  d_loss:0.4931  g_loss:1.6583
# epoch:389  d_loss:0.3338  g_loss:2.2201
# epoch:390  d_loss:0.5274  g_loss:1.8933
# epoch:391  d_loss:0.3481  g_loss:1.8916
# epoch:392  d_loss:0.3676  g_loss:1.9252
# epoch:393  d_loss:0.2594  g_loss:2.2599
# epoch:394  d_loss:0.3298  g_loss:2.2336
# epoch:395  d_loss:0.2276  g_loss:2.4950
# epoch:396  d_loss:0.2645  g_loss:2.3403
# epoch:397  d_loss:0.2974  g_loss:2.2058
# epoch:398  d_loss:0.3934  g_loss:2.3061
# epoch:399  d_loss:0.2427  g_loss:2.4046
# epoch:400  d_loss:0.2947  g_loss:2.6335
# epoch:401  d_loss:0.3814  g_loss:2.3534
# epoch:402  d_loss:0.2900  g_loss:3.0547
# epoch:403  d_loss:0.2083  g_loss:3.0104
# epoch:404  d_loss:0.3027  g_loss:3.3887
# epoch:405  d_loss:0.2563  g_loss:2.6389
# epoch:406  d_loss:0.2713  g_loss:2.3391
# epoch:407  d_loss:0.2023  g_loss:2.2868
# epoch:408  d_loss:0.2345  g_loss:2.7293
# epoch:409  d_loss:0.2053  g_loss:3.0943
# epoch:410  d_loss:0.2095  g_loss:2.7131
# epoch:411  d_loss:0.2125  g_loss:2.8832
# epoch:412  d_loss:0.2270  g_loss:2.5955
# epoch:413  d_loss:0.1905  g_loss:2.2098
# epoch:414  d_loss:0.2693  g_loss:2.4796
# epoch:415  d_loss:0.3513  g_loss:2.4462
# epoch:416  d_loss:0.3022  g_loss:2.8984
# epoch:417  d_loss:0.2128  g_loss:3.3835
# epoch:418  d_loss:0.2272  g_loss:3.4333
# epoch:419  d_loss:0.3318  g_loss:2.7984
# epoch:420  d_loss:0.4142  g_loss:2.0395
# epoch:421  d_loss:0.2287  g_loss:2.1308
# epoch:422  d_loss:0.2506  g_loss:2.6341
# epoch:423  d_loss:0.3445  g_loss:2.7123
# epoch:424  d_loss:0.3628  g_loss:3.0698
# epoch:425  d_loss:0.2257  g_loss:3.1920
# epoch:426  d_loss:0.2788  g_loss:3.2350
# epoch:427  d_loss:0.3434  g_loss:2.8225
# epoch:428  d_loss:0.3463  g_loss:2.6071
# epoch:429  d_loss:0.4875  g_loss:2.0844
# epoch:430  d_loss:0.3244  g_loss:2.6256
# epoch:431  d_loss:0.3162  g_loss:2.5551
# epoch:432  d_loss:0.3617  g_loss:2.1878
# epoch:433  d_loss:0.3590  g_loss:2.3180
# epoch:434  d_loss:0.4324  g_loss:1.9362
# epoch:435  d_loss:0.4270  g_loss:2.2218
# epoch:436  d_loss:0.3250  g_loss:2.4086
# epoch:437  d_loss:0.3437  g_loss:2.5090
# epoch:438  d_loss:0.3999  g_loss:1.8556
# epoch:439  d_loss:0.2326  g_loss:2.4724
# epoch:440  d_loss:0.4516  g_loss:1.9828
# epoch:441  d_loss:0.4182  g_loss:2.0670
# epoch:442  d_loss:0.3395  g_loss:2.8809
# epoch:443  d_loss:0.2982  g_loss:2.9619
# epoch:444  d_loss:0.5193  g_loss:2.1229
# epoch:445  d_loss:0.3348  g_loss:1.9457
# epoch:446  d_loss:0.3294  g_loss:2.0091
# epoch:447  d_loss:0.3625  g_loss:2.1976
# epoch:448  d_loss:0.3671  g_loss:2.0706
# epoch:449  d_loss:0.3387  g_loss:2.0901
# epoch:450  d_loss:0.3270  g_loss:2.2581
# epoch:451  d_loss:0.3132  g_loss:3.2072
# epoch:452  d_loss:0.3204  g_loss:2.6537
# epoch:453  d_loss:0.2852  g_loss:2.0561
# epoch:454  d_loss:0.2932  g_loss:1.8521
# epoch:455  d_loss:0.2725  g_loss:2.3429
# epoch:456  d_loss:0.3736  g_loss:2.0794
# epoch:457  d_loss:0.2000  g_loss:2.6429
# epoch:458  d_loss:0.2205  g_loss:2.3162
# epoch:459  d_loss:0.1845  g_loss:2.8780
# epoch:460  d_loss:0.1768  g_loss:2.7426
# epoch:461  d_loss:0.2975  g_loss:2.3973
# epoch:462  d_loss:0.2466  g_loss:2.6331
# epoch:463  d_loss:0.1746  g_loss:2.5516
# epoch:464  d_loss:0.1787  g_loss:2.5762
# epoch:465  d_loss:0.1993  g_loss:2.8318
# epoch:466  d_loss:0.2323  g_loss:2.6859
# epoch:467  d_loss:0.1862  g_loss:2.7391
# epoch:468  d_loss:0.1624  g_loss:2.6292
# epoch:469  d_loss:0.2061  g_loss:2.7389
# epoch:470  d_loss:0.2066  g_loss:2.9105
# epoch:471  d_loss:0.2789  g_loss:3.0109
# epoch:472  d_loss:0.1819  g_loss:3.1740
# epoch:473  d_loss:0.1203  g_loss:3.2927
# epoch:474  d_loss:0.2247  g_loss:2.8229
# epoch:475  d_loss:0.1427  g_loss:2.7766
# epoch:476  d_loss:0.1946  g_loss:2.7267
# epoch:477  d_loss:0.1378  g_loss:2.9465
# epoch:478  d_loss:0.1207  g_loss:3.5198
# epoch:479  d_loss:0.1573  g_loss:4.0848
# epoch:480  d_loss:0.1942  g_loss:3.1784
# epoch:481  d_loss:0.1885  g_loss:2.5654
# epoch:482  d_loss:0.3192  g_loss:2.2482
# epoch:483  d_loss:0.2058  g_loss:2.6768
# epoch:484  d_loss:0.0829  g_loss:3.6584
# epoch:485  d_loss:0.2398  g_loss:3.3735
# epoch:486  d_loss:0.1990  g_loss:3.0494
# epoch:487  d_loss:0.2320  g_loss:2.2753
# epoch:488  d_loss:0.2360  g_loss:1.9951
# epoch:489  d_loss:0.1518  g_loss:3.0878
# epoch:490  d_loss:0.2259  g_loss:3.2553
# epoch:491  d_loss:0.1928  g_loss:4.0065
# epoch:492  d_loss:0.3449  g_loss:2.6576
# epoch:493  d_loss:0.2237  g_loss:2.2733
# epoch:494  d_loss:0.2872  g_loss:1.9273
# epoch:495  d_loss:0.1966  g_loss:2.6278
# epoch:496  d_loss:0.2033  g_loss:2.7696
# epoch:497  d_loss:0.2707  g_loss:2.7876
# epoch:498  d_loss:0.2148  g_loss:2.2808
# epoch:499  d_loss:0.2897  g_loss:1.7409
# epoch:500  d_loss:0.2149  g_loss:2.6390
# epoch:501  d_loss:0.2491  g_loss:3.0725
# epoch:502  d_loss:0.2426  g_loss:3.3791
# epoch:503  d_loss:0.1950  g_loss:3.4034
# epoch:504  d_loss:0.2940  g_loss:2.4658
# epoch:505  d_loss:0.3533  g_loss:2.7488
# epoch:506  d_loss:0.3248  g_loss:3.0512
# epoch:507  d_loss:0.1651  g_loss:4.0343
# epoch:508  d_loss:0.1519  g_loss:3.9306
# epoch:509  d_loss:0.2457  g_loss:2.8011
# epoch:510  d_loss:0.2218  g_loss:2.3921
# epoch:511  d_loss:0.2691  g_loss:2.8108
# epoch:512  d_loss:0.3505  g_loss:2.7994
# epoch:513  d_loss:0.2239  g_loss:2.8921
# epoch:514  d_loss:0.2206  g_loss:3.1562
# epoch:515  d_loss:0.2150  g_loss:2.5470
# epoch:516  d_loss:0.2020  g_loss:2.1140
# epoch:517  d_loss:0.2316  g_loss:2.8136
# epoch:518  d_loss:0.1739  g_loss:3.0285
# epoch:519  d_loss:0.2801  g_loss:2.5438
# epoch:520  d_loss:0.2281  g_loss:2.1541
# epoch:521  d_loss:0.2481  g_loss:2.1318
# epoch:522  d_loss:0.2163  g_loss:2.5788
# epoch:523  d_loss:0.1820  g_loss:2.9683
# epoch:524  d_loss:0.1932  g_loss:3.0817
# epoch:525  d_loss:0.1728  g_loss:2.9738
# epoch:526  d_loss:0.1799  g_loss:2.2310
# epoch:527  d_loss:0.1593  g_loss:2.6456
# epoch:528  d_loss:0.2141  g_loss:2.6280
# epoch:529  d_loss:0.1912  g_loss:3.1128
# epoch:530  d_loss:0.2056  g_loss:2.4113
# epoch:531  d_loss:0.1861  g_loss:2.8908
# epoch:532  d_loss:0.1796  g_loss:3.0265
# epoch:533  d_loss:0.1447  g_loss:3.3131
# epoch:534  d_loss:0.0995  g_loss:3.4473
# epoch:535  d_loss:0.1271  g_loss:3.7936
# epoch:536  d_loss:0.1755  g_loss:3.3923
# epoch:537  d_loss:0.1301  g_loss:3.2132
# epoch:538  d_loss:0.1481  g_loss:3.1518
# epoch:539  d_loss:0.1967  g_loss:2.7736
# epoch:540  d_loss:0.2357  g_loss:3.0435
# epoch:541  d_loss:0.0921  g_loss:3.3344
# epoch:542  d_loss:0.1476  g_loss:3.4493
# epoch:543  d_loss:0.1437  g_loss:2.8685
# epoch:544  d_loss:0.2010  g_loss:2.2611
# epoch:545  d_loss:0.1618  g_loss:2.9174
# epoch:546  d_loss:0.2016  g_loss:2.9575
# epoch:547  d_loss:0.1946  g_loss:2.9443
# epoch:548  d_loss:0.1450  g_loss:2.4452
# epoch:549  d_loss:0.2594  g_loss:2.6813
# epoch:550  d_loss:0.3351  g_loss:2.3867
# epoch:551  d_loss:0.1401  g_loss:3.3719
# epoch:552  d_loss:0.3741  g_loss:3.2892
# epoch:553  d_loss:0.4294  g_loss:1.2162
# epoch:554  d_loss:0.3750  g_loss:1.7510
# epoch:555  d_loss:0.1874  g_loss:3.4104
# epoch:556  d_loss:0.1942  g_loss:4.5408
# epoch:557  d_loss:0.1849  g_loss:3.3010
# epoch:558  d_loss:0.3966  g_loss:1.8104
# epoch:559  d_loss:0.3311  g_loss:1.5246
# epoch:560  d_loss:0.3742  g_loss:1.9165
# epoch:561  d_loss:0.2539  g_loss:3.2776
# epoch:562  d_loss:0.1661  g_loss:4.0271
# epoch:563  d_loss:0.2770  g_loss:3.8749
# epoch:564  d_loss:0.4444  g_loss:2.4862
# epoch:565  d_loss:0.2705  g_loss:1.6864
# epoch:566  d_loss:0.2932  g_loss:2.7213
# epoch:567  d_loss:0.1454  g_loss:2.9895
# epoch:568  d_loss:0.1492  g_loss:4.3240
# epoch:569  d_loss:0.1951  g_loss:3.6999
# epoch:570  d_loss:0.4036  g_loss:2.7735
# epoch:571  d_loss:0.2311  g_loss:2.5931
# epoch:572  d_loss:0.1937  g_loss:1.6084
# epoch:573  d_loss:0.3396  g_loss:2.0338
# epoch:574  d_loss:0.1851  g_loss:2.0224
# epoch:575  d_loss:0.2061  g_loss:2.5669
# epoch:576  d_loss:0.1675  g_loss:3.0140
# epoch:577  d_loss:0.3986  g_loss:2.4670
# epoch:578  d_loss:0.2994  g_loss:2.1819
# epoch:579  d_loss:0.1986  g_loss:2.0889
# epoch:580  d_loss:0.1417  g_loss:2.7489
# epoch:581  d_loss:0.1800  g_loss:2.5462
# epoch:582  d_loss:0.3846  g_loss:1.9373
# epoch:583  d_loss:0.2595  g_loss:3.2283
# epoch:584  d_loss:0.2595  g_loss:3.5492
# epoch:585  d_loss:0.3213  g_loss:3.2495
# epoch:586  d_loss:0.2495  g_loss:3.2082
# epoch:587  d_loss:0.3061  g_loss:2.8389
# epoch:588  d_loss:0.4267  g_loss:3.3821
# epoch:589  d_loss:0.4448  g_loss:2.6400
# epoch:590  d_loss:0.6616  g_loss:1.6731
# epoch:591  d_loss:0.3027  g_loss:2.2954
# epoch:592  d_loss:0.2387  g_loss:3.3228
# epoch:593  d_loss:0.3503  g_loss:3.3984
# epoch:594  d_loss:0.2902  g_loss:2.1765
# epoch:595  d_loss:0.5194  g_loss:1.5684
# epoch:596  d_loss:0.3712  g_loss:1.4654
# epoch:597  d_loss:0.3022  g_loss:1.7608
# epoch:598  d_loss:0.2818  g_loss:2.1834
# epoch:599  d_loss:0.3056  g_loss:2.1038
# epoch:600  d_loss:0.3739  g_loss:1.6413
# epoch:601  d_loss:0.3964  g_loss:1.0756
# epoch:602  d_loss:0.4974  g_loss:1.3291
# epoch:603  d_loss:0.6231  g_loss:1.1565
# epoch:604  d_loss:0.5412  g_loss:1.5162
# epoch:605  d_loss:0.6129  g_loss:1.5132
# epoch:606  d_loss:0.6452  g_loss:2.1267
# epoch:607  d_loss:0.5520  g_loss:1.9376
# epoch:608  d_loss:0.4692  g_loss:1.1350
# epoch:609  d_loss:0.5204  g_loss:1.3332
# epoch:610  d_loss:0.4137  g_loss:0.8659
# epoch:611  d_loss:0.9798  g_loss:0.8858
# epoch:612  d_loss:0.6379  g_loss:1.2875
# epoch:613  d_loss:0.8674  g_loss:1.4230
# epoch:614  d_loss:1.0100  g_loss:1.9552
# epoch:615  d_loss:0.5648  g_loss:2.0885
# epoch:616  d_loss:0.5756  g_loss:2.3376
# epoch:617  d_loss:0.5831  g_loss:1.5912
# epoch:618  d_loss:1.1171  g_loss:1.3366
# epoch:619  d_loss:0.9597  g_loss:1.4924
# epoch:620  d_loss:1.4217  g_loss:2.0600
# epoch:621  d_loss:1.5300  g_loss:2.0323
# epoch:622  d_loss:0.8103  g_loss:2.9953
# epoch:623  d_loss:0.4436  g_loss:5.3265
# epoch:624  d_loss:0.6199  g_loss:4.7934
# epoch:625  d_loss:0.3112  g_loss:2.3468
# epoch:626  d_loss:1.1390  g_loss:0.7794
# epoch:627  d_loss:1.4441  g_loss:0.1040
# epoch:628  d_loss:1.6110  g_loss:0.2165
# epoch:629  d_loss:0.9401  g_loss:1.0865
# epoch:630  d_loss:0.3581  g_loss:3.3176
# epoch:631  d_loss:0.3123  g_loss:3.8886
# epoch:632  d_loss:0.5849  g_loss:4.4771
# epoch:633  d_loss:0.4127  g_loss:3.4533
# epoch:634  d_loss:0.3831  g_loss:2.1262
# epoch:635  d_loss:0.2965  g_loss:1.7270
# epoch:636  d_loss:0.5127  g_loss:2.0972
# epoch:637  d_loss:0.4427  g_loss:2.5403
# epoch:638  d_loss:0.4535  g_loss:3.7937
# epoch:639  d_loss:0.8301  g_loss:2.9430
# epoch:640  d_loss:1.7294  g_loss:3.6297
# epoch:641  d_loss:2.2358  g_loss:1.8366
# epoch:642  d_loss:1.0994  g_loss:1.8334
# epoch:643  d_loss:0.4482  g_loss:3.9563
# epoch:644  d_loss:0.4511  g_loss:6.5299
# epoch:645  d_loss:0.7765  g_loss:7.1090
# epoch:646  d_loss:0.6421  g_loss:6.2269
# epoch:647  d_loss:0.4224  g_loss:5.1890
# epoch:648  d_loss:0.3756  g_loss:4.0493
# epoch:649  d_loss:0.8112  g_loss:3.1719
# epoch:650  d_loss:0.4668  g_loss:2.4087
# epoch:651  d_loss:0.9513  g_loss:2.2163
# epoch:652  d_loss:0.6408  g_loss:1.5713
# epoch:653  d_loss:0.3751  g_loss:1.9046
# epoch:654  d_loss:0.4831  g_loss:1.6693
# epoch:655  d_loss:0.3825  g_loss:1.7444
# epoch:656  d_loss:0.5883  g_loss:1.5734
# epoch:657  d_loss:0.6101  g_loss:1.5588
# epoch:658  d_loss:0.6504  g_loss:1.2692
# epoch:659  d_loss:0.7647  g_loss:1.3685
# epoch:660  d_loss:0.6514  g_loss:1.2424
# epoch:661  d_loss:0.5220  g_loss:1.5437
# epoch:662  d_loss:0.3217  g_loss:1.7846
# epoch:663  d_loss:0.4044  g_loss:2.1659
# epoch:664  d_loss:0.2820  g_loss:2.5802
# epoch:665  d_loss:0.1976  g_loss:3.1187
# epoch:666  d_loss:0.3903  g_loss:2.3802
# epoch:667  d_loss:0.1948  g_loss:2.8215
# epoch:668  d_loss:0.3052  g_loss:2.6885
# epoch:669  d_loss:0.4405  g_loss:2.0116
# epoch:670  d_loss:0.2662  g_loss:2.2383
# epoch:671  d_loss:0.4845  g_loss:2.3410
# epoch:672  d_loss:0.5854  g_loss:1.9737
# epoch:673  d_loss:0.6254  g_loss:1.9492
# epoch:674  d_loss:0.7417  g_loss:1.9343
# epoch:675  d_loss:0.6320  g_loss:1.7212
# epoch:676  d_loss:0.8125  g_loss:1.8072
# epoch:677  d_loss:0.9402  g_loss:1.2045
# epoch:678  d_loss:0.7787  g_loss:1.2157
# epoch:679  d_loss:0.6732  g_loss:1.7649
# epoch:680  d_loss:0.6060  g_loss:1.9117
# epoch:681  d_loss:0.4613  g_loss:2.2910
# epoch:682  d_loss:0.4899  g_loss:2.4507
# epoch:683  d_loss:0.4337  g_loss:2.5050
# epoch:684  d_loss:0.3138  g_loss:2.1558
# epoch:685  d_loss:0.2939  g_loss:2.3299
# epoch:686  d_loss:0.3837  g_loss:1.7963
# epoch:687  d_loss:0.3262  g_loss:1.7236
# epoch:688  d_loss:0.2691  g_loss:2.1478
# epoch:689  d_loss:0.2679  g_loss:2.1047
# epoch:690  d_loss:0.4670  g_loss:2.0467
# epoch:691  d_loss:0.4309  g_loss:2.0846
# epoch:692  d_loss:0.3033  g_loss:2.1861
# epoch:693  d_loss:0.3420  g_loss:1.8879
# epoch:694  d_loss:0.5501  g_loss:1.7561
# epoch:695  d_loss:0.5705  g_loss:1.2015
# epoch:696  d_loss:0.4057  g_loss:1.5665
# epoch:697  d_loss:0.6047  g_loss:1.4860
# epoch:698  d_loss:0.4254  g_loss:1.7153
# epoch:699  d_loss:0.4876  g_loss:1.5503
# epoch:700  d_loss:0.3344  g_loss:1.4217
# epoch:701  d_loss:0.3567  g_loss:1.6367
# epoch:702  d_loss:0.4079  g_loss:1.4728
# epoch:703  d_loss:0.4900  g_loss:1.6374
# epoch:704  d_loss:0.3435  g_loss:1.5524
# epoch:705  d_loss:0.3518  g_loss:1.7702
# epoch:706  d_loss:0.4458  g_loss:1.4055
# epoch:707  d_loss:0.2839  g_loss:1.4060
# epoch:708  d_loss:0.4979  g_loss:1.4708
# epoch:709  d_loss:0.3266  g_loss:1.5658
# epoch:710  d_loss:0.3434  g_loss:1.6225
# epoch:711  d_loss:0.3908  g_loss:1.4624
# epoch:712  d_loss:0.4444  g_loss:1.4834
# epoch:713  d_loss:0.4829  g_loss:1.3778
# epoch:714  d_loss:0.4345  g_loss:1.3920
# epoch:715  d_loss:0.4406  g_loss:1.3609
# epoch:716  d_loss:0.3225  g_loss:1.7087
# epoch:717  d_loss:0.3266  g_loss:1.7720
# epoch:718  d_loss:0.4551  g_loss:1.3920
# epoch:719  d_loss:0.4388  g_loss:1.6000
# epoch:720  d_loss:0.4842  g_loss:1.2427
# epoch:721  d_loss:0.4265  g_loss:1.3192
# epoch:722  d_loss:0.5002  g_loss:1.1486
# epoch:723  d_loss:0.4267  g_loss:1.2470
# epoch:724  d_loss:0.5373  g_loss:1.2400
# epoch:725  d_loss:0.4034  g_loss:1.4863
# epoch:726  d_loss:0.3440  g_loss:1.8219
# epoch:727  d_loss:0.4620  g_loss:1.7286
# epoch:728  d_loss:0.4760  g_loss:1.8340
# epoch:729  d_loss:0.4149  g_loss:1.4557
# epoch:730  d_loss:0.4619  g_loss:1.4664
# epoch:731  d_loss:0.4240  g_loss:1.4021
# epoch:732  d_loss:0.3953  g_loss:1.5642
# epoch:733  d_loss:0.4348  g_loss:1.5748
# epoch:734  d_loss:0.4269  g_loss:1.6510
# epoch:735  d_loss:0.4904  g_loss:1.6237
# epoch:736  d_loss:0.3604  g_loss:1.6505
# epoch:737  d_loss:0.4417  g_loss:1.5528
# epoch:738  d_loss:0.3929  g_loss:1.5976
# epoch:739  d_loss:0.2869  g_loss:1.7743
# epoch:740  d_loss:0.4001  g_loss:1.6841
# epoch:741  d_loss:0.4122  g_loss:1.6294
# epoch:742  d_loss:0.4339  g_loss:1.3950
# epoch:743  d_loss:0.2747  g_loss:1.5323
# epoch:744  d_loss:0.4132  g_loss:1.4058
# epoch:745  d_loss:0.3301  g_loss:1.7470
# epoch:746  d_loss:0.5452  g_loss:1.5909
# epoch:747  d_loss:0.4424  g_loss:1.7233
# epoch:748  d_loss:0.3644  g_loss:1.5672
# epoch:749  d_loss:0.4112  g_loss:1.9306
# epoch:750  d_loss:0.5256  g_loss:1.6004
# epoch:751  d_loss:0.5331  g_loss:1.2657
# epoch:752  d_loss:0.4507  g_loss:1.0345
# epoch:753  d_loss:0.4845  g_loss:1.5690
# epoch:754  d_loss:0.4269  g_loss:1.4700
# epoch:755  d_loss:0.5188  g_loss:1.3426
# epoch:756  d_loss:0.5176  g_loss:1.2983
# epoch:757  d_loss:0.5236  g_loss:1.0567
# epoch:758  d_loss:0.5313  g_loss:1.0827
# epoch:759  d_loss:0.5318  g_loss:0.9871
# epoch:760  d_loss:0.6350  g_loss:1.1697
# epoch:761  d_loss:0.4790  g_loss:1.2780
# epoch:762  d_loss:0.7210  g_loss:1.0031
# epoch:763  d_loss:0.4893  g_loss:1.0775
# epoch:764  d_loss:0.6000  g_loss:1.0240
# epoch:765  d_loss:0.6057  g_loss:0.9361
# epoch:766  d_loss:0.5140  g_loss:1.0172
# epoch:767  d_loss:0.4471  g_loss:1.3767
# epoch:768  d_loss:0.3810  g_loss:1.4257
# epoch:769  d_loss:0.3462  g_loss:1.5130
# epoch:770  d_loss:0.4802  g_loss:1.4758
# epoch:771  d_loss:0.3735  g_loss:1.3954
# epoch:772  d_loss:0.3857  g_loss:1.4247
# epoch:773  d_loss:0.2875  g_loss:1.6075
# epoch:774  d_loss:0.3166  g_loss:1.5224
# epoch:775  d_loss:0.3717  g_loss:1.6448
# epoch:776  d_loss:0.3359  g_loss:1.4807
# epoch:777  d_loss:0.3427  g_loss:1.6113
# epoch:778  d_loss:0.3818  g_loss:1.3499
# epoch:779  d_loss:0.3997  g_loss:1.4672
# epoch:780  d_loss:0.4873  g_loss:1.1680
# epoch:781  d_loss:0.5969  g_loss:1.1093
# epoch:782  d_loss:0.6067  g_loss:1.1744
# epoch:783  d_loss:0.8386  g_loss:1.0991
# epoch:784  d_loss:0.6882  g_loss:1.2070
# epoch:785  d_loss:0.7256  g_loss:0.9353
# epoch:786  d_loss:0.8208  g_loss:0.9700
# epoch:787  d_loss:0.9752  g_loss:0.8538
# epoch:788  d_loss:0.7420  g_loss:1.0700
# epoch:789  d_loss:0.4587  g_loss:1.3528
# epoch:790  d_loss:0.6217  g_loss:1.5080
# epoch:791  d_loss:0.5607  g_loss:1.5957
# epoch:792  d_loss:0.3993  g_loss:1.5158
# epoch:793  d_loss:0.5287  g_loss:1.5117
# epoch:794  d_loss:0.3821  g_loss:1.6086
# epoch:795  d_loss:0.4282  g_loss:1.5914
# epoch:796  d_loss:0.3729  g_loss:1.6849
# epoch:797  d_loss:0.4284  g_loss:1.6913
# epoch:798  d_loss:0.8030  g_loss:1.2944
# epoch:799  d_loss:0.5776  g_loss:1.3680
# epoch:800  d_loss:0.4321  g_loss:1.4245
# epoch:801  d_loss:0.5103  g_loss:1.2932
# epoch:802  d_loss:0.5100  g_loss:1.2210
# epoch:803  d_loss:0.5005  g_loss:1.3778
# epoch:804  d_loss:0.4831  g_loss:1.5072
# epoch:805  d_loss:0.5410  g_loss:1.6235
# epoch:806  d_loss:0.5562  g_loss:1.5774
# epoch:807  d_loss:0.4125  g_loss:1.4674
# epoch:808  d_loss:0.4056  g_loss:1.5080
# epoch:809  d_loss:0.4382  g_loss:1.7267
# epoch:810  d_loss:0.3399  g_loss:1.9282
# epoch:811  d_loss:0.3966  g_loss:1.9966
# epoch:812  d_loss:0.3589  g_loss:2.3002
# epoch:813  d_loss:0.5332  g_loss:1.8759
# epoch:814  d_loss:0.4657  g_loss:1.7896
# epoch:815  d_loss:0.6544  g_loss:1.4873
# epoch:816  d_loss:0.5413  g_loss:1.6515
# epoch:817  d_loss:0.4212  g_loss:2.1227
# epoch:818  d_loss:0.4060  g_loss:2.1475
# epoch:819  d_loss:0.4682  g_loss:2.1730
# epoch:820  d_loss:0.3483  g_loss:2.2362
# epoch:821  d_loss:0.2532  g_loss:2.2002
# epoch:822  d_loss:0.2523  g_loss:2.2287
# epoch:823  d_loss:0.1911  g_loss:2.5118
# epoch:824  d_loss:0.2360  g_loss:3.0869
# epoch:825  d_loss:0.4012  g_loss:3.5434
# epoch:826  d_loss:0.5014  g_loss:3.1929
# epoch:827  d_loss:0.2565  g_loss:3.1058
# epoch:828  d_loss:0.3268  g_loss:3.3015
# epoch:829  d_loss:0.3064  g_loss:2.6721
# epoch:830  d_loss:0.4922  g_loss:2.2417
# epoch:831  d_loss:0.3238  g_loss:2.6168
# epoch:832  d_loss:0.3636  g_loss:2.3078
# epoch:833  d_loss:0.4571  g_loss:2.5041
# epoch:834  d_loss:0.5492  g_loss:2.2861
# epoch:835  d_loss:0.6741  g_loss:2.1312
# epoch:836  d_loss:0.7440  g_loss:1.7901
# epoch:837  d_loss:0.4703  g_loss:2.4082
# epoch:838  d_loss:0.7041  g_loss:1.9993
# epoch:839  d_loss:0.7742  g_loss:1.3917
# epoch:840  d_loss:0.7462  g_loss:1.1588
# epoch:841  d_loss:0.4493  g_loss:1.6729
# epoch:842  d_loss:0.4987  g_loss:1.5188
# epoch:843  d_loss:0.4397  g_loss:1.5512
# epoch:844  d_loss:0.6739  g_loss:1.4172
# epoch:845  d_loss:0.4781  g_loss:1.9091
# epoch:846  d_loss:0.5147  g_loss:1.7153
# epoch:847  d_loss:0.5667  g_loss:1.8248
# epoch:848  d_loss:0.4568  g_loss:1.7996
# epoch:849  d_loss:0.4645  g_loss:1.8225
# epoch:850  d_loss:0.4765  g_loss:1.7185
# epoch:851  d_loss:0.3691  g_loss:2.0166
# epoch:852  d_loss:0.4887  g_loss:1.9724
# epoch:853  d_loss:0.4459  g_loss:2.0444
# epoch:854  d_loss:0.2648  g_loss:2.2142
# epoch:855  d_loss:0.3122  g_loss:2.3286
# epoch:856  d_loss:0.2421  g_loss:2.6724
# epoch:857  d_loss:0.3380  g_loss:2.5041
# epoch:858  d_loss:0.2630  g_loss:2.6985
# epoch:859  d_loss:0.2870  g_loss:2.1319
# epoch:860  d_loss:0.3014  g_loss:2.0646
# epoch:861  d_loss:0.2534  g_loss:2.2436
# epoch:862  d_loss:0.2843  g_loss:2.1137
# epoch:863  d_loss:0.2010  g_loss:2.7547
# epoch:864  d_loss:0.2507  g_loss:2.9390
# epoch:865  d_loss:0.2048  g_loss:3.0663
# epoch:866  d_loss:0.2533  g_loss:3.3858
# epoch:867  d_loss:0.1782  g_loss:3.0754
# epoch:868  d_loss:0.2958  g_loss:2.8139
# epoch:869  d_loss:0.3876  g_loss:2.3636
# epoch:870  d_loss:0.2869  g_loss:2.5402
# epoch:871  d_loss:0.3372  g_loss:2.3487
# epoch:872  d_loss:0.4180  g_loss:2.5112
# epoch:873  d_loss:0.3879  g_loss:2.3529
# epoch:874  d_loss:0.2799  g_loss:2.0871
# epoch:875  d_loss:0.5937  g_loss:2.0759
# epoch:876  d_loss:0.4217  g_loss:1.8230
# epoch:877  d_loss:0.4721  g_loss:1.9201
# epoch:878  d_loss:0.4676  g_loss:1.6559
# epoch:879  d_loss:0.4798  g_loss:1.6809
# epoch:880  d_loss:0.5620  g_loss:1.8263
# epoch:881  d_loss:0.4946  g_loss:1.8826
# epoch:882  d_loss:0.4892  g_loss:1.8859
# epoch:883  d_loss:0.6193  g_loss:1.6417
# epoch:884  d_loss:0.4442  g_loss:1.8836
# epoch:885  d_loss:0.5227  g_loss:1.4567
# epoch:886  d_loss:0.5210  g_loss:1.3751
# epoch:887  d_loss:0.5492  g_loss:1.5074
# epoch:888  d_loss:0.5268  g_loss:1.8376
# epoch:889  d_loss:0.5838  g_loss:1.8288
# epoch:890  d_loss:0.3826  g_loss:1.5908
# epoch:891  d_loss:0.5225  g_loss:1.6201
# epoch:892  d_loss:0.4163  g_loss:1.7143
# epoch:893  d_loss:0.3734  g_loss:1.5853
# epoch:894  d_loss:0.3714  g_loss:1.8325
# epoch:895  d_loss:0.4000  g_loss:1.9783
# epoch:896  d_loss:0.3073  g_loss:1.8850
# epoch:897  d_loss:0.3067  g_loss:1.7700
# epoch:898  d_loss:0.3192  g_loss:2.0054
# epoch:899  d_loss:0.2637  g_loss:2.1856
# epoch:900  d_loss:0.2305  g_loss:2.7401
# epoch:901  d_loss:0.2651  g_loss:2.2975
# epoch:902  d_loss:0.3412  g_loss:2.3260
# epoch:903  d_loss:0.2828  g_loss:2.1613
# epoch:904  d_loss:0.3086  g_loss:1.8926
# epoch:905  d_loss:0.3202  g_loss:2.0913
# epoch:906  d_loss:0.2480  g_loss:2.3396
# epoch:907  d_loss:0.3090  g_loss:2.3248
# epoch:908  d_loss:0.4516  g_loss:2.0457
# epoch:909  d_loss:0.1965  g_loss:2.3012
# epoch:910  d_loss:0.2561  g_loss:2.3046
# epoch:911  d_loss:0.4121  g_loss:1.9626
# epoch:912  d_loss:0.3111  g_loss:1.8122
# epoch:913  d_loss:0.3350  g_loss:1.7847
# epoch:914  d_loss:0.4521  g_loss:1.7253
# epoch:915  d_loss:0.5777  g_loss:2.0012
# epoch:916  d_loss:0.4228  g_loss:1.9055
# epoch:917  d_loss:0.3838  g_loss:1.9703
# epoch:918  d_loss:0.3910  g_loss:1.8324
# epoch:919  d_loss:0.4175  g_loss:2.1777
# epoch:920  d_loss:0.3494  g_loss:1.9586
# epoch:921  d_loss:0.4632  g_loss:1.7463
# epoch:922  d_loss:0.5651  g_loss:1.5620
# epoch:923  d_loss:0.5360  g_loss:1.5486
# epoch:924  d_loss:0.4668  g_loss:1.5931
# epoch:925  d_loss:0.4620  g_loss:1.7870
# epoch:926  d_loss:0.4189  g_loss:1.6052
# epoch:927  d_loss:0.5429  g_loss:1.4766
# epoch:928  d_loss:0.4769  g_loss:1.3872
# epoch:929  d_loss:0.4953  g_loss:1.5545
# epoch:930  d_loss:0.3213  g_loss:1.7610
# epoch:931  d_loss:0.5063  g_loss:1.9223
# epoch:932  d_loss:0.3672  g_loss:1.9691
# epoch:933  d_loss:0.3106  g_loss:2.2997
# epoch:934  d_loss:0.3155  g_loss:1.8224
# epoch:935  d_loss:0.3277  g_loss:2.1676
# epoch:936  d_loss:0.2862  g_loss:2.0119
# epoch:937  d_loss:0.3229  g_loss:2.0359
# epoch:938  d_loss:0.3591  g_loss:1.9004
# epoch:939  d_loss:0.2806  g_loss:2.2738
# epoch:940  d_loss:0.3711  g_loss:2.1933
# epoch:941  d_loss:0.2848  g_loss:2.6598
# epoch:942  d_loss:0.3188  g_loss:2.9722
# epoch:943  d_loss:0.3625  g_loss:2.2498
# epoch:944  d_loss:0.3918  g_loss:1.7461
# epoch:945  d_loss:0.3367  g_loss:1.7188
# epoch:946  d_loss:0.4049  g_loss:1.8847
# epoch:947  d_loss:0.2786  g_loss:2.5811
# epoch:948  d_loss:0.4193  g_loss:2.1498
# epoch:949  d_loss:0.4584  g_loss:2.3039
# epoch:950  d_loss:0.3727  g_loss:2.1001
# epoch:951  d_loss:0.4380  g_loss:1.8652
# epoch:952  d_loss:0.5006  g_loss:1.6914
# epoch:953  d_loss:0.3907  g_loss:1.9908
# epoch:954  d_loss:0.3859  g_loss:2.2241
# epoch:955  d_loss:0.5216  g_loss:1.9151
# epoch:956  d_loss:0.3514  g_loss:2.0903
# epoch:957  d_loss:0.4406  g_loss:2.0897
# epoch:958  d_loss:0.4406  g_loss:1.8141
# epoch:959  d_loss:0.6170  g_loss:1.5592
# epoch:960  d_loss:0.3874  g_loss:1.7804
# epoch:961  d_loss:0.3914  g_loss:2.0519
# epoch:962  d_loss:0.3786  g_loss:2.1279
# epoch:963  d_loss:0.4186  g_loss:2.1212
# epoch:964  d_loss:0.3470  g_loss:2.6996
# epoch:965  d_loss:0.3867  g_loss:2.2755
# epoch:966  d_loss:0.4147  g_loss:1.8691
# epoch:967  d_loss:0.4875  g_loss:1.4736
# epoch:968  d_loss:0.3581  g_loss:2.1623
# epoch:969  d_loss:0.3186  g_loss:2.5317
# epoch:970  d_loss:0.3682  g_loss:2.5506
# epoch:971  d_loss:0.3561  g_loss:2.1199
# epoch:972  d_loss:0.4048  g_loss:2.2028
# epoch:973  d_loss:0.2627  g_loss:2.0591
# epoch:974  d_loss:0.4273  g_loss:1.9615
# epoch:975  d_loss:0.2805  g_loss:2.5714
# epoch:976  d_loss:0.2347  g_loss:2.4133
# epoch:977  d_loss:0.2793  g_loss:2.7956
# epoch:978  d_loss:0.3208  g_loss:2.1025
# epoch:979  d_loss:0.3382  g_loss:1.8868
# epoch:980  d_loss:0.3284  g_loss:1.8739
# epoch:981  d_loss:0.3382  g_loss:2.1145
# epoch:982  d_loss:0.3044  g_loss:2.5179
# epoch:983  d_loss:0.3251  g_loss:2.2483
# epoch:984  d_loss:0.5279  g_loss:1.9283
# epoch:985  d_loss:0.3980  g_loss:2.1615
# epoch:986  d_loss:0.2793  g_loss:2.2709
# epoch:987  d_loss:0.5183  g_loss:2.0371
# epoch:988  d_loss:0.5215  g_loss:2.2431
# epoch:989  d_loss:0.4423  g_loss:2.0148
# epoch:990  d_loss:0.4562  g_loss:2.1172
# epoch:991  d_loss:0.6425  g_loss:1.9758
# epoch:992  d_loss:0.7638  g_loss:1.5281
# epoch:993  d_loss:0.5643  g_loss:1.7431
# epoch:994  d_loss:0.8033  g_loss:1.4085
# epoch:995  d_loss:0.8886  g_loss:1.3187
# epoch:996  d_loss:0.7403  g_loss:1.4458
# epoch:997  d_loss:0.9122  g_loss:1.1287
# epoch:998  d_loss:0.8773  g_loss:1.1015
# epoch:999  d_loss:0.5608  g_loss:1.4718
# epoch:1000  d_loss:0.4314  g_loss:1.6366
# epoch:1001  d_loss:0.5741  g_loss:1.9107
# epoch:1002  d_loss:0.5767  g_loss:1.4617
# epoch:1003  d_loss:0.4876  g_loss:1.5865
# epoch:1004  d_loss:0.5306  g_loss:1.4151
# epoch:1005  d_loss:0.4954  g_loss:1.6103
# epoch:1006  d_loss:0.4131  g_loss:1.9113
# epoch:1007  d_loss:0.4201  g_loss:1.9231
# epoch:1008  d_loss:0.3494  g_loss:1.7431
# epoch:1009  d_loss:0.2804  g_loss:2.4302
# epoch:1010  d_loss:0.2533  g_loss:2.3418
# epoch:1011  d_loss:0.3333  g_loss:2.1022
# epoch:1012  d_loss:0.4276  g_loss:1.7560
# epoch:1013  d_loss:0.2023  g_loss:2.4581
# epoch:1014  d_loss:0.2585  g_loss:2.1837
# epoch:1015  d_loss:0.3650  g_loss:2.4411
# epoch:1016  d_loss:0.2486  g_loss:2.5081
# epoch:1017  d_loss:0.2895  g_loss:2.1945
# epoch:1018  d_loss:0.3181  g_loss:2.3134
# epoch:1019  d_loss:0.2273  g_loss:2.2757
# epoch:1020  d_loss:0.2326  g_loss:2.5498
# epoch:1021  d_loss:0.2866  g_loss:2.7532
# epoch:1022  d_loss:0.3557  g_loss:2.5373
# epoch:1023  d_loss:0.2317  g_loss:2.4005
# epoch:1024  d_loss:0.4925  g_loss:2.2406
# epoch:1025  d_loss:0.4491  g_loss:2.2428
# epoch:1026  d_loss:0.2878  g_loss:2.1796
# epoch:1027  d_loss:0.3409  g_loss:2.1279
# epoch:1028  d_loss:0.3732  g_loss:2.2582
# epoch:1029  d_loss:0.3228  g_loss:2.8146
# epoch:1030  d_loss:0.2166  g_loss:2.4065
# epoch:1031  d_loss:0.3395  g_loss:2.3586
# epoch:1032  d_loss:0.4737  g_loss:1.6615
# epoch:1033  d_loss:0.3460  g_loss:1.9501
# epoch:1034  d_loss:0.4122  g_loss:1.7719
# epoch:1035  d_loss:0.3453  g_loss:2.3964
# epoch:1036  d_loss:0.5783  g_loss:1.8826
# epoch:1037  d_loss:0.4667  g_loss:1.8487
# epoch:1038  d_loss:0.4536  g_loss:1.6776
# epoch:1039  d_loss:0.4472  g_loss:2.0763
# epoch:1040  d_loss:0.4700  g_loss:1.9421
# epoch:1041  d_loss:0.5286  g_loss:2.1179
# epoch:1042  d_loss:0.4351  g_loss:1.9007
# epoch:1043  d_loss:0.3812  g_loss:2.0808
# epoch:1044  d_loss:0.4641  g_loss:1.6973
# epoch:1045  d_loss:0.4171  g_loss:1.8448
# epoch:1046  d_loss:0.3044  g_loss:2.1094
# epoch:1047  d_loss:0.2537  g_loss:2.4071
# epoch:1048  d_loss:0.3032  g_loss:2.6693
# epoch:1049  d_loss:0.2245  g_loss:2.5007
# epoch:1050  d_loss:0.4245  g_loss:2.4061
# epoch:1051  d_loss:0.2378  g_loss:2.1587
# epoch:1052  d_loss:0.3110  g_loss:2.2264
# epoch:1053  d_loss:0.3687  g_loss:2.1198
# epoch:1054  d_loss:0.2812  g_loss:2.3871
# epoch:1055  d_loss:0.4145  g_loss:2.4996
# epoch:1056  d_loss:0.2043  g_loss:2.3828
# epoch:1057  d_loss:0.2800  g_loss:2.4619
# epoch:1058  d_loss:0.2950  g_loss:2.2666
# epoch:1059  d_loss:0.3528  g_loss:2.5411
# epoch:1060  d_loss:0.2620  g_loss:2.4304
# epoch:1061  d_loss:0.3820  g_loss:2.2376
# epoch:1062  d_loss:0.3686  g_loss:2.0941
# epoch:1063  d_loss:0.5259  g_loss:1.8602
# epoch:1064  d_loss:0.6283  g_loss:1.9583
# epoch:1065  d_loss:0.3500  g_loss:2.0962
# epoch:1066  d_loss:0.4423  g_loss:2.0935
# epoch:1067  d_loss:0.6533  g_loss:2.2087
# epoch:1068  d_loss:0.5325  g_loss:1.6213
# epoch:1069  d_loss:0.4022  g_loss:1.7473
# epoch:1070  d_loss:0.7010  g_loss:1.3682
# epoch:1071  d_loss:0.4063  g_loss:1.8370
# epoch:1072  d_loss:0.7740  g_loss:1.7254
# epoch:1073  d_loss:0.4886  g_loss:1.7072
# epoch:1074  d_loss:0.3944  g_loss:2.1210
# epoch:1075  d_loss:0.4924  g_loss:2.0348
# epoch:1076  d_loss:0.5339  g_loss:1.4311
# epoch:1077  d_loss:0.4296  g_loss:1.7098
# epoch:1078  d_loss:0.5264  g_loss:1.8839
# epoch:1079  d_loss:0.3931  g_loss:2.2226
# epoch:1080  d_loss:0.3844  g_loss:2.1342
# epoch:1081  d_loss:0.3214  g_loss:2.2741
# epoch:1082  d_loss:0.4884  g_loss:2.5743
# epoch:1083  d_loss:0.5371  g_loss:2.3761
# epoch:1084  d_loss:0.4919  g_loss:1.9482
# epoch:1085  d_loss:0.4842  g_loss:1.6803
# epoch:1086  d_loss:0.6051  g_loss:1.7221
# epoch:1087  d_loss:0.3776  g_loss:2.0045
# epoch:1088  d_loss:0.2522  g_loss:2.3029
# epoch:1089  d_loss:0.3229  g_loss:2.4493
# epoch:1090  d_loss:0.3222  g_loss:2.0888
# epoch:1091  d_loss:0.3832  g_loss:2.1820
# epoch:1092  d_loss:0.2369  g_loss:2.2654
# epoch:1093  d_loss:0.3423  g_loss:2.1646
# epoch:1094  d_loss:0.2302  g_loss:2.2672
# epoch:1095  d_loss:0.2646  g_loss:2.1381
# epoch:1096  d_loss:0.3163  g_loss:1.9802
# epoch:1097  d_loss:0.2434  g_loss:2.4799
# epoch:1098  d_loss:0.2508  g_loss:2.5891
# epoch:1099  d_loss:0.3739  g_loss:2.0764
# epoch:1100  d_loss:0.3049  g_loss:2.0007
# epoch:1101  d_loss:0.2902  g_loss:2.1198
# epoch:1102  d_loss:0.2163  g_loss:2.3255
# epoch:1103  d_loss:0.3327  g_loss:2.6276
# epoch:1104  d_loss:0.3211  g_loss:2.1863
# epoch:1105  d_loss:0.3068  g_loss:2.3765
# epoch:1106  d_loss:0.2625  g_loss:2.5090
# epoch:1107  d_loss:0.5664  g_loss:2.0355
# epoch:1108  d_loss:0.3305  g_loss:2.0597
# epoch:1109  d_loss:0.3263  g_loss:1.8112
# epoch:1110  d_loss:0.3722  g_loss:1.7680
# epoch:1111  d_loss:0.5119  g_loss:2.3351
# epoch:1112  d_loss:0.5314  g_loss:2.2308
# epoch:1113  d_loss:0.3882  g_loss:3.0351
# epoch:1114  d_loss:0.4481  g_loss:2.4095
# epoch:1115  d_loss:0.4643  g_loss:2.3232
# epoch:1116  d_loss:0.5126  g_loss:1.7537
# epoch:1117  d_loss:0.3604  g_loss:1.8304
# epoch:1118  d_loss:0.3875  g_loss:2.1355
# epoch:1119  d_loss:0.4217  g_loss:2.2635
# epoch:1120  d_loss:0.3789  g_loss:2.4704
# epoch:1121  d_loss:0.3774  g_loss:2.2466
# epoch:1122  d_loss:0.4781  g_loss:1.9375
# epoch:1123  d_loss:0.5948  g_loss:1.5865
# epoch:1124  d_loss:0.5120  g_loss:1.7000
# epoch:1125  d_loss:0.5178  g_loss:1.9625
# epoch:1126  d_loss:0.5168  g_loss:1.8855
# epoch:1127  d_loss:0.5580  g_loss:2.8570
# epoch:1128  d_loss:0.3679  g_loss:2.1991
# epoch:1129  d_loss:0.6306  g_loss:1.7156
# epoch:1130  d_loss:0.4728  g_loss:2.1213
# epoch:1131  d_loss:0.5683  g_loss:2.1150
# epoch:1132  d_loss:0.3409  g_loss:2.2429
# epoch:1133  d_loss:0.2874  g_loss:2.0754
# epoch:1134  d_loss:0.4572  g_loss:2.0936
# epoch:1135  d_loss:0.5193  g_loss:1.4535
# epoch:1136  d_loss:0.6301  g_loss:1.7590
# epoch:1137  d_loss:0.4521  g_loss:2.0245
# epoch:1138  d_loss:0.5053  g_loss:2.1280
# epoch:1139  d_loss:0.3762  g_loss:2.1856
# epoch:1140  d_loss:0.5433  g_loss:1.9393
# epoch:1141  d_loss:0.4944  g_loss:1.7494
# epoch:1142  d_loss:0.5062  g_loss:1.7189
# epoch:1143  d_loss:0.3858  g_loss:1.5088
# epoch:1144  d_loss:0.5590  g_loss:1.6457
# epoch:1145  d_loss:0.6622  g_loss:1.5456
# epoch:1146  d_loss:0.4933  g_loss:1.3278
# epoch:1147  d_loss:0.4449  g_loss:1.6581
# epoch:1148  d_loss:0.4081  g_loss:1.8962
# epoch:1149  d_loss:0.5708  g_loss:1.4955
# epoch:1150  d_loss:0.5258  g_loss:1.8451
# epoch:1151  d_loss:0.3180  g_loss:2.1537
# epoch:1152  d_loss:0.5118  g_loss:1.8635
# epoch:1153  d_loss:0.4799  g_loss:1.6314
# epoch:1154  d_loss:0.5060  g_loss:1.4542
# epoch:1155  d_loss:0.3731  g_loss:1.7483
# epoch:1156  d_loss:0.4843  g_loss:1.6971
# epoch:1157  d_loss:0.4141  g_loss:1.7626
# epoch:1158  d_loss:0.3933  g_loss:1.7903
# epoch:1159  d_loss:0.5045  g_loss:1.6819
# epoch:1160  d_loss:0.3658  g_loss:1.5709
# epoch:1161  d_loss:0.4101  g_loss:1.8299
# epoch:1162  d_loss:0.4634  g_loss:2.1831
# epoch:1163  d_loss:0.3699  g_loss:2.1369
# epoch:1164  d_loss:0.5413  g_loss:1.9356
# epoch:1165  d_loss:0.4181  g_loss:2.1015
# epoch:1166  d_loss:0.2786  g_loss:2.0319
# epoch:1167  d_loss:0.4880  g_loss:1.9525
# epoch:1168  d_loss:0.3353  g_loss:1.9837
# epoch:1169  d_loss:0.4692  g_loss:1.8117
# epoch:1170  d_loss:0.4138  g_loss:1.8614
# epoch:1171  d_loss:0.3659  g_loss:2.0488
# epoch:1172  d_loss:0.4020  g_loss:1.6192
# epoch:1173  d_loss:0.4167  g_loss:2.2070
# epoch:1174  d_loss:0.3431  g_loss:2.2775
# epoch:1175  d_loss:0.3252  g_loss:2.0728
# epoch:1176  d_loss:0.3255  g_loss:2.3732
# epoch:1177  d_loss:0.4510  g_loss:2.2341
# epoch:1178  d_loss:0.3813  g_loss:1.9402
# ...
# epoch:3619  d_loss:0.4483  g_loss:1.6933
# epoch:3620  d_loss:0.4099  g_loss:1.4945
# epoch:3621  d_loss:0.4996  g_loss:1.6657
# epoch:3622  d_loss:0.5270  g_loss:1.7308
# epoch:3623  d_loss:0.5065  g_loss:1.9185
# epoch:3624  d_loss:0.4888  g_loss:1.7488
# epoch:3625  d_loss:0.5020  g_loss:1.2392
# epoch:3626  d_loss:0.4769  g_loss:1.3743
# epoch:3627  d_loss:0.4281  g_loss:1.7679
# epoch:3628  d_loss:0.5543  g_loss:1.9721
# epoch:3629  d_loss:0.4895  g_loss:1.7784
# epoch:3630  d_loss:0.4790  g_loss:1.6713
# epoch:3631  d_loss:0.5094  g_loss:1.5165
# epoch:3632  d_loss:0.4589  g_loss:1.3894
# epoch:3633  d_loss:0.6828  g_loss:1.4294
# epoch:3634  d_loss:0.5850  g_loss:1.3633
# epoch:3635  d_loss:0.5423  g_loss:1.7453
# epoch:3636  d_loss:0.4576  g_loss:1.7586
# epoch:3637  d_loss:0.6271  g_loss:1.6421
# epoch:3638  d_loss:0.4469  g_loss:1.2845
# epoch:3639  d_loss:0.5114  g_loss:1.9056
# epoch:3640  d_loss:0.6327  g_loss:1.7028
# epoch:3641  d_loss:0.5134  g_loss:1.5407
# epoch:3642  d_loss:0.5989  g_loss:1.1160
# epoch:3643  d_loss:0.5567  g_loss:0.9681
# epoch:3644  d_loss:0.5695  g_loss:1.2130
# epoch:3645  d_loss:0.4283  g_loss:1.2723
# epoch:3646  d_loss:0.5445  g_loss:1.4112
# epoch:3647  d_loss:0.4022  g_loss:1.6239
# epoch:3648  d_loss:0.4596  g_loss:1.8714
# epoch:3649  d_loss:0.6091  g_loss:1.7430
# epoch:3650  d_loss:0.5060  g_loss:1.5960
# epoch:3651  d_loss:0.5395  g_loss:1.2924
# epoch:3652  d_loss:0.5284  g_loss:1.6427
# epoch:3653  d_loss:0.3952  g_loss:1.2323
# epoch:3654  d_loss:0.6414  g_loss:1.2525
# epoch:3655  d_loss:0.5175  g_loss:1.6398
# epoch:3656  d_loss:0.5336  g_loss:1.7493
# epoch:3657  d_loss:0.4469  g_loss:1.6460
# epoch:3658  d_loss:0.4845  g_loss:1.3782
# epoch:3659  d_loss:0.3560  g_loss:1.5876
# epoch:3660  d_loss:0.4532  g_loss:1.6429
# epoch:3661  d_loss:0.4657  g_loss:1.8028
# epoch:3662  d_loss:0.4242  g_loss:1.8371
# epoch:3663  d_loss:0.3960  g_loss:2.0997
# epoch:3664  d_loss:0.4112  g_loss:1.7181
# epoch:3665  d_loss:0.6363  g_loss:1.5977
# epoch:3666  d_loss:0.5458  g_loss:1.7884
# epoch:3667  d_loss:0.4716  g_loss:1.6568
# epoch:3668  d_loss:0.4804  g_loss:1.4615
# epoch:3669  d_loss:0.5813  g_loss:1.6286
# epoch:3670  d_loss:0.3737  g_loss:1.9018
# epoch:3671  d_loss:0.5695  g_loss:1.3801
# epoch:3672  d_loss:0.6467  g_loss:1.2960
# epoch:3673  d_loss:0.4374  g_loss:1.6155
# epoch:3674  d_loss:0.4600  g_loss:1.3926
# epoch:3675  d_loss:0.4798  g_loss:1.6759
# epoch:3676  d_loss:0.5206  g_loss:1.6836
# epoch:3677  d_loss:0.4765  g_loss:1.6222
# epoch:3678  d_loss:0.6126  g_loss:1.4755
# epoch:3679  d_loss:0.4729  g_loss:1.5015
# epoch:3680  d_loss:0.6755  g_loss:1.2363
# epoch:3681  d_loss:0.6320  g_loss:1.1190
# epoch:3682  d_loss:0.5995  g_loss:1.2159
# epoch:3683  d_loss:0.6223  g_loss:1.5416
# epoch:3684  d_loss:0.4968  g_loss:1.3274
# epoch:3685  d_loss:0.5993  g_loss:1.4984
# epoch:3686  d_loss:0.4471  g_loss:1.3137
# epoch:3687  d_loss:0.5801  g_loss:1.3325
# epoch:3688  d_loss:0.6601  g_loss:1.2159
# epoch:3689  d_loss:0.6192  g_loss:1.2694
# epoch:3690  d_loss:0.6013  g_loss:1.6647
# epoch:3691  d_loss:0.6086  g_loss:1.4866
# epoch:3692  d_loss:0.5609  g_loss:1.7366
# epoch:3693  d_loss:0.5705  g_loss:1.6169
# epoch:3694  d_loss:0.5192  g_loss:1.6829
# epoch:3695  d_loss:0.5856  g_loss:1.3421
# epoch:3696  d_loss:0.5735  g_loss:1.3828
# epoch:3697  d_loss:0.4715  g_loss:1.6002
# epoch:3698  d_loss:0.5416  g_loss:1.5053
# epoch:3699  d_loss:0.4873  g_loss:1.8010
# epoch:3700  d_loss:0.4326  g_loss:1.5171
# epoch:3701  d_loss:0.4050  g_loss:1.6705
# epoch:3702  d_loss:0.5175  g_loss:1.5201
# epoch:3703  d_loss:0.4574  g_loss:1.4953
# epoch:3704  d_loss:0.4406  g_loss:1.4749
# epoch:3705  d_loss:0.4713  g_loss:1.5038
# epoch:3706  d_loss:0.4773  g_loss:1.3845
# epoch:3707  d_loss:0.4684  g_loss:1.7857
# epoch:3708  d_loss:0.4645  g_loss:1.6262
# epoch:3709  d_loss:0.5300  g_loss:1.4757
# epoch:3710  d_loss:0.5295  g_loss:1.1704
# epoch:3711  d_loss:0.4571  g_loss:1.6754
# epoch:3712  d_loss:0.2929  g_loss:1.8977
# epoch:3713  d_loss:0.5506  g_loss:1.5992
# epoch:3714  d_loss:0.5299  g_loss:1.6746
# epoch:3715  d_loss:0.4680  g_loss:1.7049
# epoch:3716  d_loss:0.5880  g_loss:1.6402
# epoch:3717  d_loss:0.4130  g_loss:1.6468
# epoch:3718  d_loss:0.4640  g_loss:1.4526
# epoch:3719  d_loss:0.4703  g_loss:1.5246
# epoch:3720  d_loss:0.4102  g_loss:1.6368
# epoch:3721  d_loss:0.4741  g_loss:1.9803
# epoch:3722  d_loss:0.4381  g_loss:1.6366
# epoch:3723  d_loss:0.4324  g_loss:1.8469
# epoch:3724  d_loss:0.3743  g_loss:1.5431
# epoch:3725  d_loss:0.7689  g_loss:1.6561
# epoch:3726  d_loss:0.3820  g_loss:1.3446
# epoch:3727  d_loss:0.5632  g_loss:1.3361
# epoch:3728  d_loss:0.5476  g_loss:1.3572
# epoch:3729  d_loss:0.3988  g_loss:1.4958
# epoch:3730  d_loss:0.7328  g_loss:1.3935
# epoch:3731  d_loss:0.4838  g_loss:1.6877
# epoch:3732  d_loss:0.5855  g_loss:1.7499
# epoch:3733  d_loss:0.4220  g_loss:1.9772
# epoch:3734  d_loss:0.4752  g_loss:1.5153
# epoch:3735  d_loss:0.5697  g_loss:1.4829
# epoch:3736  d_loss:0.4633  g_loss:1.4392
# epoch:3737  d_loss:0.4248  g_loss:1.6927
# epoch:3738  d_loss:0.5227  g_loss:1.6019
# epoch:3739  d_loss:0.5278  g_loss:1.5103
# epoch:3740  d_loss:0.4203  g_loss:1.2313
# epoch:3741  d_loss:0.4806  g_loss:1.6624
# epoch:3742  d_loss:0.5228  g_loss:1.6647
# epoch:3743  d_loss:0.5755  g_loss:1.4617
# epoch:3744  d_loss:0.4291  g_loss:1.6233
# epoch:3745  d_loss:0.4805  g_loss:1.8793
# epoch:3746  d_loss:0.5652  g_loss:1.7731
# epoch:3747  d_loss:0.5309  g_loss:2.2153
# epoch:3748  d_loss:0.5291  g_loss:1.5726
# epoch:3749  d_loss:0.4575  g_loss:1.5778
# epoch:3750  d_loss:0.6317  g_loss:1.1149
# epoch:3751  d_loss:0.5675  g_loss:1.2316
# epoch:3752  d_loss:0.4465  g_loss:1.4711
# epoch:3753  d_loss:0.5558  g_loss:1.9113
# epoch:3754  d_loss:0.7507  g_loss:1.6189
# epoch:3755  d_loss:0.5172  g_loss:1.3598
# epoch:3756  d_loss:0.5753  g_loss:1.2491
# epoch:3757  d_loss:0.5269  g_loss:1.3267
# epoch:3758  d_loss:0.4834  g_loss:1.5256
# epoch:3759  d_loss:0.5054  g_loss:1.7123
# epoch:3760  d_loss:0.4941  g_loss:1.7386
# epoch:3761  d_loss:0.4836  g_loss:1.9205
# epoch:3762  d_loss:0.4663  g_loss:1.3455
# epoch:3763  d_loss:0.6083  g_loss:1.3441
# epoch:3764  d_loss:0.5578  g_loss:1.3167
# epoch:3765  d_loss:0.4475  g_loss:1.3702
# epoch:3766  d_loss:0.4578  g_loss:1.9398
# epoch:3767  d_loss:0.4077  g_loss:2.2631
# epoch:3768  d_loss:0.5495  g_loss:2.1250
# epoch:3769  d_loss:0.4848  g_loss:1.5165
# epoch:3770  d_loss:0.3946  g_loss:1.5378
# epoch:3771  d_loss:0.4181  g_loss:1.5529
# epoch:3772  d_loss:0.5397  g_loss:1.5841
# epoch:3773  d_loss:0.3777  g_loss:1.5623
# epoch:3774  d_loss:0.3625  g_loss:2.0402
# epoch:3775  d_loss:0.4068  g_loss:1.8455
# epoch:3776  d_loss:0.4661  g_loss:1.7844
# epoch:3777  d_loss:0.6133  g_loss:1.5347
# epoch:3778  d_loss:0.5476  g_loss:1.4579
# epoch:3779  d_loss:0.5483  g_loss:1.5434
# epoch:3780  d_loss:0.3957  g_loss:1.8773
# epoch:3781  d_loss:0.5333  g_loss:1.8255
# epoch:3782  d_loss:0.5466  g_loss:1.7333
# epoch:3783  d_loss:0.5972  g_loss:1.1908
# epoch:3784  d_loss:0.6932  g_loss:1.0810
# epoch:3785  d_loss:0.7010  g_loss:1.2351
# epoch:3786  d_loss:0.5191  g_loss:1.6002
# epoch:3787  d_loss:0.4908  g_loss:2.0159
# epoch:3788  d_loss:0.7379  g_loss:1.7681
# epoch:3789  d_loss:0.6942  g_loss:1.8504
# epoch:3790  d_loss:0.5656  g_loss:1.3845
# epoch:3791  d_loss:0.7584  g_loss:0.9934
# epoch:3792  d_loss:0.4437  g_loss:1.3300
# epoch:3793  d_loss:0.5613  g_loss:1.3891
# epoch:3794  d_loss:0.5629  g_loss:1.5125
# epoch:3795  d_loss:0.5758  g_loss:1.4391
# epoch:3796  d_loss:0.5479  g_loss:1.6145
# epoch:3797  d_loss:0.4537  g_loss:1.2809
# epoch:3798  d_loss:0.5224  g_loss:0.9811
# epoch:3799  d_loss:0.4422  g_loss:1.2414
# epoch:3800  d_loss:0.6072  g_loss:1.3476
# epoch:3801  d_loss:0.3718  g_loss:1.6923
# epoch:3802  d_loss:0.5009  g_loss:1.4759
# epoch:3803  d_loss:0.4053  g_loss:1.6033
# epoch:3804  d_loss:0.3598  g_loss:2.1115
# epoch:3805  d_loss:0.5387  g_loss:1.9497
# epoch:3806  d_loss:0.5414  g_loss:1.6332
# epoch:3807  d_loss:0.4567  g_loss:1.4942
# epoch:3808  d_loss:0.4914  g_loss:1.5352
# epoch:3809  d_loss:0.4026  g_loss:1.4867
# epoch:3810  d_loss:0.4187  g_loss:1.8040
# epoch:3811  d_loss:0.3958  g_loss:1.9438
# epoch:3812  d_loss:0.4075  g_loss:1.7066
# epoch:3813  d_loss:0.3744  g_loss:1.6039
# epoch:3814  d_loss:0.5034  g_loss:1.8745
# epoch:3815  d_loss:0.3219  g_loss:1.7694
# epoch:3816  d_loss:0.3507  g_loss:2.0649
# epoch:3817  d_loss:0.4559  g_loss:1.7207
# epoch:3818  d_loss:0.4350  g_loss:1.4702
# epoch:3819  d_loss:0.3875  g_loss:1.6979
# epoch:3820  d_loss:0.5675  g_loss:1.5976
# epoch:3821  d_loss:0.4628  g_loss:1.6610
# epoch:3822  d_loss:0.4931  g_loss:1.3574
# epoch:3823  d_loss:0.5141  g_loss:1.5017
# epoch:3824  d_loss:0.4716  g_loss:1.4713
# epoch:3825  d_loss:0.7360  g_loss:1.1877
# epoch:3826  d_loss:0.4814  g_loss:1.5747
# epoch:3827  d_loss:0.5117  g_loss:1.3896
# epoch:3828  d_loss:0.4289  g_loss:1.8782
# epoch:3829  d_loss:0.6313  g_loss:1.7594
# epoch:3830  d_loss:0.5320  g_loss:1.7073
# epoch:3831  d_loss:0.5450  g_loss:1.8982
# epoch:3832  d_loss:0.4785  g_loss:1.6362
# epoch:3833  d_loss:0.4025  g_loss:1.7476
# epoch:3834  d_loss:0.5508  g_loss:1.4405
# epoch:3835  d_loss:0.4797  g_loss:1.9490
# epoch:3836  d_loss:0.5909  g_loss:1.6528
# epoch:3837  d_loss:0.5371  g_loss:1.8642
# epoch:3838  d_loss:0.5105  g_loss:1.9071
# epoch:3839  d_loss:0.5011  g_loss:1.7363
# epoch:3840  d_loss:0.4131  g_loss:1.8348
# epoch:3841  d_loss:0.4929  g_loss:1.7945
# epoch:3842  d_loss:0.5215  g_loss:2.0810
# epoch:3843  d_loss:0.4128  g_loss:1.8174
# epoch:3844  d_loss:0.3998  g_loss:2.2322
# epoch:3845  d_loss:0.4567  g_loss:2.1651
# epoch:3846  d_loss:0.4130  g_loss:1.7736
# epoch:3847  d_loss:0.4870  g_loss:2.1630
# epoch:3848  d_loss:0.4032  g_loss:1.8367
# epoch:3849  d_loss:0.2708  g_loss:2.3624
# epoch:3850  d_loss:0.4466  g_loss:2.0610
# epoch:3851  d_loss:0.3351  g_loss:2.3071
# epoch:3852  d_loss:0.3722  g_loss:2.7853
# epoch:3853  d_loss:0.4006  g_loss:2.5811
# epoch:3854  d_loss:0.5093  g_loss:1.9970
# epoch:3855  d_loss:0.6037  g_loss:1.5445
# epoch:3856  d_loss:0.4953  g_loss:1.5507
# epoch:3857  d_loss:0.4118  g_loss:1.7361
# epoch:3858  d_loss:0.5235  g_loss:1.4102
# epoch:3859  d_loss:0.5466  g_loss:1.1878
# epoch:3860  d_loss:0.5479  g_loss:1.6831
# epoch:3861  d_loss:0.5202  g_loss:1.9631
# epoch:3862  d_loss:0.5449  g_loss:1.8216
# epoch:3863  d_loss:0.6667  g_loss:1.8235
# epoch:3864  d_loss:0.5284  g_loss:1.7473
# epoch:3865  d_loss:0.6214  g_loss:1.2790
# epoch:3866  d_loss:0.5587  g_loss:1.2916
# epoch:3867  d_loss:0.5664  g_loss:1.2186
# epoch:3868  d_loss:0.5705  g_loss:1.3053
# epoch:3869  d_loss:0.5180  g_loss:2.1827
# epoch:3870  d_loss:0.4476  g_loss:2.1459
# epoch:3871  d_loss:0.3815  g_loss:1.6066
# epoch:3872  d_loss:0.6073  g_loss:1.3138
# epoch:3873  d_loss:0.4553  g_loss:1.4233
# epoch:3874  d_loss:0.6422  g_loss:1.2338
# epoch:3875  d_loss:0.4730  g_loss:1.4168
# epoch:3876  d_loss:0.4342  g_loss:1.4721
# epoch:3877  d_loss:0.4755  g_loss:2.1886
# epoch:3878  d_loss:0.5799  g_loss:1.7753
# epoch:3879  d_loss:0.4909  g_loss:1.6564
# epoch:3880  d_loss:0.3730  g_loss:1.3802
# epoch:3881  d_loss:0.5255  g_loss:1.7463
# epoch:3882  d_loss:0.4076  g_loss:2.0003
# epoch:3883  d_loss:0.3744  g_loss:1.9374
# epoch:3884  d_loss:0.4535  g_loss:1.9021
# epoch:3885  d_loss:0.4953  g_loss:1.8089
# epoch:3886  d_loss:0.4115  g_loss:1.5718
# epoch:3887  d_loss:0.4756  g_loss:1.6070
# epoch:3888  d_loss:0.4571  g_loss:1.3749
# epoch:3889  d_loss:0.3619  g_loss:1.0935
# epoch:3890  d_loss:0.4894  g_loss:1.5546
# epoch:3891  d_loss:0.3613  g_loss:1.9809
# epoch:3892  d_loss:0.4101  g_loss:2.2321
# epoch:3893  d_loss:0.5075  g_loss:2.0591
# epoch:3894  d_loss:0.6705  g_loss:1.6249
# epoch:3895  d_loss:0.3338  g_loss:1.9185
# epoch:3896  d_loss:0.5390  g_loss:1.8889
# epoch:3897  d_loss:0.3286  g_loss:2.2062
# epoch:3898  d_loss:0.5286  g_loss:1.7891
# epoch:3899  d_loss:0.5247  g_loss:1.7970
# epoch:3900  d_loss:0.5168  g_loss:1.6522
# epoch:3901  d_loss:0.3939  g_loss:1.7252
# epoch:3902  d_loss:0.5495  g_loss:1.7232
# epoch:3903  d_loss:0.5488  g_loss:1.6543
# epoch:3904  d_loss:0.4133  g_loss:1.5476
# epoch:3905  d_loss:0.6781  g_loss:1.1740
# epoch:3906  d_loss:0.5128  g_loss:1.4500
# epoch:3907  d_loss:0.5293  g_loss:1.9395
# epoch:3908  d_loss:0.6590  g_loss:1.6963
# epoch:3909  d_loss:0.6437  g_loss:2.0813
# epoch:3910  d_loss:0.4851  g_loss:1.5888
# epoch:3911  d_loss:0.4878  g_loss:1.6920
# epoch:3912  d_loss:0.4273  g_loss:1.4637
# epoch:3913  d_loss:0.5120  g_loss:1.6807
# epoch:3914  d_loss:0.5402  g_loss:1.2201
# epoch:3915  d_loss:0.5864  g_loss:1.2290
# epoch:3916  d_loss:0.4773  g_loss:1.7764
# epoch:3917  d_loss:0.4477  g_loss:1.6597
# epoch:3918  d_loss:0.5399  g_loss:1.7033
# epoch:3919  d_loss:0.5878  g_loss:1.7044
# epoch:3920  d_loss:0.4757  g_loss:1.6536
# epoch:3921  d_loss:0.4364  g_loss:1.6792
# epoch:3922  d_loss:0.4256  g_loss:1.5805
# epoch:3923  d_loss:0.4210  g_loss:1.7015
# epoch:3924  d_loss:0.6006  g_loss:1.8156
# epoch:3925  d_loss:0.5145  g_loss:1.4892
# epoch:3926  d_loss:0.4760  g_loss:1.6775
# epoch:3927  d_loss:0.5135  g_loss:1.5468
# epoch:3928  d_loss:0.4779  g_loss:1.4387
# epoch:3929  d_loss:0.4829  g_loss:1.6408
# epoch:3930  d_loss:0.4289  g_loss:1.7955
# epoch:3931  d_loss:0.4405  g_loss:1.6466
# epoch:3932  d_loss:0.4015  g_loss:1.7753
# epoch:3933  d_loss:0.4023  g_loss:1.9037
# epoch:3934  d_loss:0.5757  g_loss:1.6063
# epoch:3935  d_loss:0.4800  g_loss:1.6141
# epoch:3936  d_loss:0.4963  g_loss:1.7950
# epoch:3937  d_loss:0.4396  g_loss:1.7236
# epoch:3938  d_loss:0.5017  g_loss:1.4125
# epoch:3939  d_loss:0.5289  g_loss:1.2317
# epoch:3940  d_loss:0.4758  g_loss:1.4618
# epoch:3941  d_loss:0.4166  g_loss:1.7504
# epoch:3942  d_loss:0.5158  g_loss:1.7581
# epoch:3943  d_loss:0.5209  g_loss:1.7983
# epoch:3944  d_loss:0.4413  g_loss:2.1453
# epoch:3945  d_loss:0.4813  g_loss:2.0796
# epoch:3946  d_loss:0.5024  g_loss:1.7629
# epoch:3947  d_loss:0.3787  g_loss:1.8631
# epoch:3948  d_loss:0.3068  g_loss:1.7378
# epoch:3949  d_loss:0.5667  g_loss:2.0035
# epoch:3950  d_loss:0.4882  g_loss:1.6974
# epoch:3951  d_loss:0.6311  g_loss:1.5754
# epoch:3952  d_loss:0.4868  g_loss:1.8546
# epoch:3953  d_loss:0.4563  g_loss:1.6824
# epoch:3954  d_loss:0.5457  g_loss:1.5645
# epoch:3955  d_loss:0.3991  g_loss:2.1450
# epoch:3956  d_loss:0.5019  g_loss:1.7559
# epoch:3957  d_loss:0.4184  g_loss:1.9290
# epoch:3958  d_loss:0.5793  g_loss:1.6026
# epoch:3959  d_loss:0.4026  g_loss:1.8920
# epoch:3960  d_loss:0.4638  g_loss:1.4772
# epoch:3961  d_loss:0.4406  g_loss:1.7285
# epoch:3962  d_loss:0.3238  g_loss:2.1732
# epoch:3963  d_loss:0.5552  g_loss:1.4174
# epoch:3964  d_loss:0.5748  g_loss:1.5474
# epoch:3965  d_loss:0.5697  g_loss:1.6070
# epoch:3966  d_loss:0.6073  g_loss:1.5026
# epoch:3967  d_loss:0.4813  g_loss:1.9183
# epoch:3968  d_loss:0.3670  g_loss:2.2532
# epoch:3969  d_loss:0.5529  g_loss:1.4409
# epoch:3970  d_loss:0.5139  g_loss:2.0152
# epoch:3971  d_loss:0.6233  g_loss:1.6150
# epoch:3972  d_loss:0.4154  g_loss:1.8362
# epoch:3973  d_loss:0.5699  g_loss:1.7357
# epoch:3974  d_loss:0.3377  g_loss:1.7394
# epoch:3975  d_loss:0.4671  g_loss:1.8252
# epoch:3976  d_loss:0.4869  g_loss:1.8582
# epoch:3977  d_loss:0.5042  g_loss:1.7077
# epoch:3978  d_loss:0.5459  g_loss:1.5427
# epoch:3979  d_loss:0.4070  g_loss:1.5779
# epoch:3980  d_loss:0.5559  g_loss:1.7059
# epoch:3981  d_loss:0.5226  g_loss:1.7938
# epoch:3982  d_loss:0.3746  g_loss:1.8795
# epoch:3983  d_loss:0.5005  g_loss:2.2322
# epoch:3984  d_loss:0.5185  g_loss:2.1346
# epoch:3985  d_loss:0.4393  g_loss:1.7657
# epoch:3986  d_loss:0.5262  g_loss:1.3605
# epoch:3987  d_loss:0.7037  g_loss:1.1951
# epoch:3988  d_loss:0.4420  g_loss:1.3826
# epoch:3989  d_loss:0.4923  g_loss:2.1219
# epoch:3990  d_loss:0.5398  g_loss:1.7360
# epoch:3991  d_loss:0.6177  g_loss:1.9200
# epoch:3992  d_loss:0.5371  g_loss:1.7512
# epoch:3993  d_loss:0.5686  g_loss:1.5741
# epoch:3994  d_loss:0.5594  g_loss:1.2092
# epoch:3995  d_loss:0.4659  g_loss:1.2957
# epoch:3996  d_loss:0.4809  g_loss:1.5069
# epoch:3997  d_loss:0.4969  g_loss:2.1142
# epoch:3998  d_loss:0.4607  g_loss:1.9082
# epoch:3999  d_loss:0.4125  g_loss:2.0002
# epoch:4000  d_loss:0.4414  g_loss:1.8015
# <ipython-input-1-88d2492157fc>:92: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axs = plt.subplots(5, 5)

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape
import matplotlib.pyplot as plt
import numpy as np

#MNIST데이터 셋을 불러옵니다.

(X_train, _), (X_test, _) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32') / 255

#생성자 모델을 만듭니다.
autoencoder = Sequential()

# 인코딩 부분입니다.
autoencoder.add(Conv2D(16, kernel_size=3, padding='same', input_shape=(28,28,1), activation='relu'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, activation='relu', padding='same'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, strides=2, padding='same', activation='relu'))

# 디코딩 부분이 이어집니다. 
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(16, kernel_size=3, activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(1, kernel_size=3, padding='same', activation='sigmoid'))

# 전체 구조를 확인해 봅니다.
autoencoder.summary()

# 컴파일 및 학습을 하는 부분입니다.
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.fit(X_train, X_train, epochs=50, batch_size=128, validation_data=(X_test, X_test))

#학습된 결과를 출력하는 부분입니다.
random_test = np.random.randint(X_test.shape[0], size=5)  #테스트할 이미지를 랜덤하게 불러옵니다.
ae_imgs = autoencoder.predict(X_test)  #앞서 만든 오토인코더 모델에 집어 넣습니다.

plt.figure(figsize=(7, 2))  #출력될 이미지의 크기를 정합니다.

for i, image_idx in enumerate(random_test):    #랜덤하게 뽑은 이미지를 차례로 나열합니다.
   ax = plt.subplot(2, 7, i + 1) 
   plt.imshow(X_test[image_idx].reshape(28, 28))  #테스트할 이미지를 먼저 그대로 보여줍니다.
   ax.axis('off')
   ax = plt.subplot(2, 7, 7 + i +1)
   plt.imshow(ae_imgs[image_idx].reshape(28, 28))  #오토인코딩 결과를 다음열에 출력합니다.
   ax.axis('off')
plt.show()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 8)         1160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 8)           0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 8)           584
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 8)           584
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 8)           584
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 14, 14, 16)        1168
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 1)         145
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2155 - val_loss: 0.1407
# Epoch 2/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1265 - val_loss: 0.1155
# Epoch 3/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1112 - val_loss: 0.1057
# Epoch 4/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1044 - val_loss: 0.1010
# Epoch 5/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1008 - val_loss: 0.0980
# Epoch 6/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0981 - val_loss: 0.0964
# Epoch 7/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0960 - val_loss: 0.0942
# Epoch 8/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0942 - val_loss: 0.0926
# Epoch 9/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0928 - val_loss: 0.0911
# Epoch 10/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0916 - val_loss: 0.0899
# Epoch 11/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0906 - val_loss: 0.0890
# Epoch 12/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0898 - val_loss: 0.0883
# Epoch 13/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0890 - val_loss: 0.0875
# Epoch 14/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0885 - val_loss: 0.0871
# Epoch 15/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0879 - val_loss: 0.0869
# Epoch 16/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0875 - val_loss: 0.0862
# Epoch 17/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0871 - val_loss: 0.0859
# Epoch 18/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0867 - val_loss: 0.0854
# Epoch 19/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0863 - val_loss: 0.0850
# Epoch 20/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0861 - val_loss: 0.0849
# Epoch 21/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0858 - val_loss: 0.0845
# Epoch 22/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0855 - val_loss: 0.0844
# Epoch 23/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0853 - val_loss: 0.0842
# Epoch 24/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0851 - val_loss: 0.0841
# Epoch 25/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0848 - val_loss: 0.0837
# Epoch 26/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0846 - val_loss: 0.0835
# Epoch 27/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0844 - val_loss: 0.0834
# Epoch 28/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0842 - val_loss: 0.0832
# Epoch 29/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0841 - val_loss: 0.0829
# Epoch 30/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0839 - val_loss: 0.0831
# Epoch 31/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0838 - val_loss: 0.0828
# Epoch 32/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0836 - val_loss: 0.0827
# Epoch 33/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0835 - val_loss: 0.0824
# Epoch 34/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0833 - val_loss: 0.0822
# Epoch 35/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0832 - val_loss: 0.0821
# Epoch 36/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0831 - val_loss: 0.0820
# Epoch 37/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0830 - val_loss: 0.0820
# Epoch 38/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0829 - val_loss: 0.0818
# Epoch 39/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0828 - val_loss: 0.0818
# Epoch 40/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0827 - val_loss: 0.0816
# Epoch 41/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0826 - val_loss: 0.0819
# Epoch 42/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0825 - val_loss: 0.0815
# Epoch 43/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0824 - val_loss: 0.0815
# Epoch 44/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0824 - val_loss: 0.0814
# Epoch 45/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0822 - val_loss: 0.0814
# Epoch 46/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0822 - val_loss: 0.0814
# Epoch 47/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0821 - val_loss: 0.0815
# Epoch 48/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0821 - val_loss: 0.0811
# Epoch 49/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0820 - val_loss: 0.0809
# Epoch 50/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0819 - val_loss: 0.0809
